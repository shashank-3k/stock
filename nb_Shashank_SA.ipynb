# %%
# !pip install streamlit

# %%
# !pip install yfinance
# !pip install python-picard

# %%
# !pip install Pillow
# !pip install pandas
# !pip install pandas-datareader

# %%
# !pip install tensorflow

# %%
# !pip install protobuf==3.20.*

# %%
import os


# import tensorflow as tf
# tf.test.gpu_device_name()
# tf.keras.backend.set_image_data_format("channels_last")

from sklearn.decomposition import FastICA
from sklearn.preprocessing import StandardScaler
import pandas as pd
#import streamlit as st
import pandas as pd
import numpy as np
import requests
import time
from PIL import Image
import pickle
import warnings
warnings.filterwarnings("ignore")
import yfinance as yf
yf.pdr_override()


#import seaborn as sns
import math
import datetime

from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense
from sklearn.metrics import mean_squared_error
#import all_function

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

import random

from functools import reduce

from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

import picard

# %%
np.random.seed(7)

# %%
stock='COST'

# %%
job=pd.read_csv(r"./job (1).csv")
job.loc[len(job)] = ['2023-02', 71.68311]
job.loc[len(job)] = ['2023-03', 71.68311]
job.loc[len(job)] = ['2023-04', 71.68311]
job.loc[len(job)] = ['2023-05', 71.68311]
job.loc[len(job)] = ['2023-06', 71.68311]
Labour=pd.read_csv(r"./Labour (1).csv")
Labour.loc[len(Labour)] = ['2023-02', 42]
Labour.loc[len(Labour)] = ['2023-03', 42]
Labour.loc[len(Labour)] = ['2023-04', 42]
Labour.loc[len(Labour)] = ['2023-05', 42]
Labour.loc[len(Labour)] = ['2023-06', 42]
Manufacture_indexing=pd.read_csv(r"./Manufacture_indexing (1).csv")
Manufacture_indexing.drop("Unnamed: 0",axis=1,inplace=True)
Manufacture_indexing.loc[len(Manufacture_indexing)] = [259.904, '02-2023']
Manufacture_indexing.loc[len(Manufacture_indexing)] = [259.904, '03-2023']
Manufacture_indexing.loc[len(Manufacture_indexing)] = [259.904, '04-2023']
Manufacture_indexing.loc[len(Manufacture_indexing)] = [259.904, '05-2023']
Manufacture_indexing.loc[len(Manufacture_indexing)] = [259.904, '06-2023']
CPI=pd.read_csv(r"./CPI (1).csv")
CPI.drop("Unnamed: 0",axis=1,inplace=True)
CPI.loc[len(CPI)] = [300.536, '2023-02']
CPI.loc[len(CPI)] = [300.536, '2023-03']
CPI.loc[len(CPI)] = [300.536, '2023-04']
CPI.loc[len(CPI)] = [300.536, '2023-05']
CPI.loc[len(CPI)] = [300.536, '2023-06']
inflation=pd.read_csv(r"./inflation (2).csv")

Housing=pd.read_csv(r"./housing_new_gg (1).csv")
Housing.loc[Housing['Year-Months'] == '2023-02', 'Housing_value'] = 377
Housing.loc[Housing['Year-Months'] == '2023-03', 'Housing_value'] = 377
Housing.loc[Housing['Year-Months'] == '2023-04', 'Housing_value'] = 377
Housing.loc[Housing['Year-Months'] == '2023-05', 'Housing_value'] = 377
Housing.loc[Housing['Year-Months'] == '2023-06', 'Housing_value'] = 377
nasdaq=pd.read_csv(r"./NASDAQCOM.csv")
nasdaq['DATE'] = pd.to_datetime(nasdaq['DATE'])
start_date = nasdaq['DATE'].max()
end_date = datetime.datetime.today().strftime('%Y-%m-%d')
date_range = pd.date_range(start=start_date, end=end_date, freq='D')
missing_dates = pd.DataFrame({'DATE': date_range})
missing_dates = missing_dates[~missing_dates['DATE'].isin(nasdaq['DATE'])]
nasdaq = pd.concat([nasdaq, missing_dates], sort=False)
nasdaq.sort_values('DATE', inplace=True)
nasdaq.reset_index(drop=True, inplace=True)
nasdaq.fillna(method='ffill', inplace=True)
nasdaq['DATE'] = nasdaq['DATE'].astype(str)

# %%
nasdaq
# Out:
#             DATE NASDAQCOM
# 0     1994-02-07    779.20
# 1     1994-02-08    782.70
# 2     1994-02-09    786.53
# 3     1994-02-10    783.42
# 4     1994-02-11    781.39
# ...          ...       ...
# 7685  2023-06-08  11855.83
# 7686  2023-06-09  11855.83
# 7687  2023-06-10  11855.83
# 7688  2023-06-11  11855.83
# 7689  2023-06-12  11855.83
#
# [7690 rows x 2 columns]

# %%
msft = yf.Ticker(stock)
data = msft.history(start="2005-01-01")
df=data.reset_index()

# %%
df
# Out:
#                           Date        Open        High         Low  \
# 0    2005-01-03 00:00:00-05:00   33.691786   34.215601   33.349559
# 1    2005-01-04 00:00:00-05:00   33.656853   33.761617   32.853672
# 2    2005-01-05 00:00:00-05:00   32.951471   33.426397   32.769880
# 3    2005-01-06 00:00:00-05:00   34.124805   34.145757   33.356542
# 4    2005-01-07 00:00:00-05:00   33.258784   33.496247   33.084179
# ...                        ...         ...         ...         ...
# 4636 2023-06-05 00:00:00-04:00  512.590027  518.919983  512.020020
# 4637 2023-06-06 00:00:00-04:00  518.250000  518.630005  512.760010
# 4638 2023-06-07 00:00:00-04:00  514.510010  519.289978  510.570007
# 4639 2023-06-08 00:00:00-04:00  512.500000  520.289978  512.500000
# 4640 2023-06-09 00:00:00-04:00  518.190002  522.059998  515.500000
#
#            Close   Volume  Dividends  Stock Splits
# 0      33.454323  2219300        0.0           0.0
# 1      32.853672  3280200        0.0           0.0
# 2      32.979408  2672900        0.0           0.0
# 3      33.454323  3771700        0.0           0.0
# 4      33.167992  2448200        0.0           0.0
# ...          ...      ...        ...           ...
# 4636  518.250000  2023500        0.0           0.0
# 4637  516.260010  1410300        0.0           0.0
# 4638  511.230011  1784700        0.0           0.0
# 4639  520.090027  1530400        0.0           0.0
# 4640  517.280029  1287300        0.0           0.0
#
# [4641 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4641 entries, 0 to 4640
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          4641 non-null   datetime64[ns, America/New_York]
#  1   Open          4641 non-null   float64
#  2   High          4641 non-null   float64
#  3   Low           4641 non-null   float64
#  4   Close         4641 non-null   float64
#  5   Volume        4641 non-null   int64
#  6   Dividends     4641 non-null   float64
#  7   Stock Splits  4641 non-null   float64
# dtypes: datetime64[ns, America/New_York](1), float64(6), int64(1)
# memory usage: 290.2 KB

# %%
def get_columns(stock):
    msft = yf.Ticker(stock)
    data = msft.history(start="2005-01-01")
    df=data.reset_index()

    df['DATE_new'] = df['Date'].apply(lambda x: x.strftime('%Y-%m-%d'))

    df['Year'] = pd.DatetimeIndex(df['Date']).year
    df['month_num'] = pd.DatetimeIndex(df['Date']).month
    df['month_num'] = df['month_num'].apply(lambda x: f"{x:02d}")

    df['Year_month'] = df['Year'].astype(str) + '-' + df['month_num'].astype(str)
    df['month_Year'] = df['month_num'].astype(str) + '-' + df['Year'].astype(str)

    merged_df = pd.merge(df,job, left_on='Year_month', right_on='TIME')

    merged_df = pd.merge(merged_df,Labour, left_on='Year_month', right_on='Time')

    
    merged_df = pd.merge(merged_df,Manufacture_indexing, left_on='month_Year', right_on='Month_year')

    #CPI.drop("Unnamed: 0",axis=1,inplace=True)
    merged_df = pd.merge(merged_df,CPI, left_on='TIME', right_on='Month_years')

    merged_df = pd.merge(merged_df,inflation, left_on='TIME', right_on='Year-Month')

    merged_df = pd.merge(merged_df,Housing, left_on='TIME', right_on='Year-Months')
    merged_df=pd.merge(merged_df,nasdaq, left_on='DATE_new', right_on='DATE')

#     df=merged_df.drop(['Month_year',"DATE","DATE_new", 'Month_years',"Time","Year","Year-month"],axis=1)
#     df=df.drop(["month_num","month_Year","TIME","Year-Months"], axis=1)

    df=merged_df.drop(['Month_year',"DATE","DATE_new", 'Month_years',"Year-Month", "Time","Year","Year_month","month_num","month_Year","TIME","Year-Months"], axis=1)

    df['NASDAQCOM']=df.NASDAQCOM.astype(float)

    df['inflation_Value']=df.inflation_Value.astype(float)
    
    return df

# %%
dffffff=get_columns(stock)

# %%
dffffff
# Out:
#                           Date        Open        High         Low  \
# 0    2005-01-03 00:00:00-05:00   33.691774   34.215589   33.349547
# 1    2005-01-04 00:00:00-05:00   33.656853   33.761617   32.853672
# 2    2005-01-05 00:00:00-05:00   32.951448   33.426374   32.769857
# 3    2005-01-06 00:00:00-05:00   34.124794   34.145746   33.356530
# 4    2005-01-07 00:00:00-05:00   33.258746   33.496209   33.084141
# ...                        ...         ...         ...         ...
# 4636 2023-06-05 00:00:00-04:00  512.590027  518.919983  512.020020
# 4637 2023-06-06 00:00:00-04:00  518.250000  518.630005  512.760010
# 4638 2023-06-07 00:00:00-04:00  514.510010  519.289978  510.570007
# 4639 2023-06-08 00:00:00-04:00  512.500000  520.289978  512.500000
# 4640 2023-06-09 00:00:00-04:00  518.190002  522.059998  515.500000
#
#            Close   Volume  Dividends  Stock Splits  Job_Value  Labour_values  \
# 0      33.454311  2219300        0.0           0.0   71.31039             30
# 1      32.853672  3280200        0.0           0.0   71.31039             30
# 2      32.979385  2672900        0.0           0.0   71.31039             30
# 3      33.454311  3771700        0.0           0.0   71.31039             30
# 4      33.167953  2448200        0.0           0.0   71.31039             30
# ...          ...      ...        ...           ...        ...            ...
# 4636  518.250000  2023500        0.0           0.0   71.68311             42
# 4637  516.260010  1410300        0.0           0.0   71.68311             42
# 4638  511.230011  1784700        0.0           0.0   71.68311             42
# 4639  520.090027  1530400        0.0           0.0   71.68311             42
# 4640  517.280029  1287300        0.0           0.0   71.68311             42
#
#       Manufacturing_Value  CPI_Value  inflation_Value  Housing_value  \
# 0                 150.900    191.600             2.97          227.8
# 1                 150.900    191.600             2.97          227.8
# 2                 150.900    191.600             2.97          227.8
# 3                 150.900    191.600             2.97          227.8
# 4                 150.900    191.600             2.97          227.8
# ...                   ...        ...              ...            ...
# 4636              259.904    300.536             6.41          377.0
# 4637              259.904    300.536             6.41          377.0
# 4638              259.904    300.536             6.41          377.0
# 4639              259.904    300.536             6.41          377.0
# 4640              259.904    300.536             6.41          377.0
#
#       NASDAQCOM
# 0       2152.15
# 1       2107.86
# 2       2091.24
# 3       2090.00
# 4       2088.61
# ...         ...
# 4636   11855.83
# 4637   11855.83
# 4638   11855.83
# 4639   11855.83
# 4640   11855.83
#
# [4641 rows x 15 columns]

# %%
api_key = "L82N6LJGLR5DP8L9"
ticker_symbol = stock

url = f"https://www.alphavantage.co/query?function=BALANCE_SHEET&symbol={ticker_symbol}&apikey={api_key}"
response = requests.get(url)

data = response.json()["annualReports"]
balance_sheet = pd.DataFrame(data).set_index("fiscalDateEnding").iloc[::-1].drop(columns="reportedCurrency")

url = f"https://www.alphavantage.co/query?function=INCOME_STATEMENT&symbol={ticker_symbol}&apikey={api_key}"
response = requests.get(url)

data = response.json()["annualReports"]
income_statement = pd.DataFrame(data).set_index("fiscalDateEnding").iloc[::-1].drop(columns="reportedCurrency")

url = f"https://www.alphavantage.co/query?function=CASH_FLOW&symbol={ticker_symbol}&apikey={api_key}"
response = requests.get(url)

data = response.json()["annualReports"]
cash_flow = pd.DataFrame(data).set_index("fiscalDateEnding").iloc[::-1].drop(columns="reportedCurrency")

previous_row = balance_sheet.iloc[-1].tolist()
new_df = pd.DataFrame([previous_row], columns=balance_sheet.columns)
balance_sheet = balance_sheet.reset_index()
balance_sheet = pd.concat([balance_sheet, new_df], axis=0, ignore_index=True)
balance_sheet.at[5, 'fiscalDateEnding'] = '2023-12-31'
balance_sheet.set_index('fiscalDateEnding', inplace=True)

previous_row = income_statement.iloc[-1].tolist()
new_df = pd.DataFrame([previous_row], columns=income_statement.columns)
income_statement = income_statement.reset_index()
income_statement = pd.concat([income_statement, new_df], axis=0, ignore_index=True)
income_statement.at[5, 'fiscalDateEnding'] = '2023-12-31'
income_statement.set_index('fiscalDateEnding', inplace=True)

previous_row = cash_flow.iloc[-1].tolist()
new_df = pd.DataFrame([previous_row], columns=cash_flow.columns)
cash_flow = cash_flow.reset_index()
cash_flow = pd.concat([cash_flow, new_df], axis=0, ignore_index=True)
cash_flow.at[5, 'fiscalDateEnding'] = '2023-12-31'
cash_flow.set_index('fiscalDateEnding', inplace=True)

dfs = [balance_sheet, income_statement, cash_flow]
dfs = reduce(lambda left,right: pd.merge(left,right,on='fiscalDateEnding'), dfs)
dfs = dfs.apply(pd.to_numeric, errors='coerce')
nan_value_columns=dfs[dfs.columns[dfs.isna().any()]]
dfs=dfs.drop(nan_value_columns.columns,axis=1)

# %%
dfs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6 entries, 2018-09-02 to 2023-12-31
# Data columns (total 67 columns):
#  #   Column                                                     Non-Null Count  Dtype
# ---  ------                                                     --------------  -----
#  0   totalAssets                                                6 non-null      int64
#  1   totalCurrentAssets                                         6 non-null      int64
#  2   cashAndCashEquivalentsAtCarryingValue                      6 non-null      int64
#  3   cashAndShortTermInvestments                                6 non-null      int64
#  4   inventory                                                  6 non-null      int64
#  5   currentNetReceivables                                      6 non-null      int64
#  6   totalNonCurrentAssets                                      6 non-null      int64
#  7   propertyPlantEquipment                                     6 non-null      int64
#  8   accumulatedDepreciationAmortizationPPE                     6 non-null      int64
#  9   shortTermInvestments                                       6 non-null      int64
#  10  otherCurrentAssets                                         6 non-null      int64
#  11  otherNonCurrentAssets                                      6 non-null      int64
#  12  totalLiabilities                                           6 non-null      int64
#  13  totalCurrentLiabilities                                    6 non-null      int64
#  14  currentAccountsPayable                                     6 non-null      int64
#  15  deferredRevenue                                            6 non-null      int64
#  16  currentDebt                                                6 non-null      int64
#  17  shortTermDebt                                              6 non-null      int64
#  18  totalNonCurrentLiabilities                                 6 non-null      int64
#  19  longTermDebt                                               6 non-null      int64
#  20  currentLongTermDebt                                        6 non-null      int64
#  21  longTermDebtNoncurrent                                     6 non-null      int64
#  22  shortLongTermDebtTotal                                     6 non-null      int64
#  23  otherCurrentLiabilities                                    6 non-null      int64
#  24  otherNonCurrentLiabilities                                 6 non-null      int64
#  25  totalShareholderEquity                                     6 non-null      int64
#  26  retainedEarnings                                           6 non-null      int64
#  27  commonStock                                                6 non-null      int64
#  28  commonStockSharesOutstanding                               6 non-null      int64
#  29  grossProfit                                                6 non-null      int64
#  30  totalRevenue                                               6 non-null      int64
#  31  costOfRevenue                                              6 non-null      int64
#  32  costofGoodsAndServicesSold                                 6 non-null      int64
#  33  operatingIncome                                            6 non-null      int64
#  34  sellingGeneralAndAdministrative                            6 non-null      int64
#  35  operatingExpenses                                          6 non-null      int64
#  36  netInterestIncome                                          6 non-null      int64
#  37  interestIncome                                             6 non-null      int64
#  38  interestExpense                                            6 non-null      int64
#  39  nonInterestIncome                                          6 non-null      int64
#  40  depreciationAndAmortization                                6 non-null      int64
#  41  incomeBeforeTax                                            6 non-null      int64
#  42  incomeTaxExpense                                           6 non-null      int64
#  43  interestAndDebtExpense                                     6 non-null      int64
#  44  netIncomeFromContinuingOperations                          6 non-null      int64
#  45  comprehensiveIncomeNetOfTax                                6 non-null      int64
#  46  ebit                                                       6 non-null      int64
#  47  ebitda                                                     6 non-null      int64
#  48  netIncome_x                                                6 non-null      int64
#  49  operatingCashflow                                          6 non-null      int64
#  50  paymentsForOperatingActivities                             6 non-null      int64
#  51  changeInOperatingLiabilities                               6 non-null      int64
#  52  changeInOperatingAssets                                    6 non-null      int64
#  53  depreciationDepletionAndAmortization                       6 non-null      int64
#  54  capitalExpenditures                                        6 non-null      int64
#  55  changeInInventory                                          6 non-null      int64
#  56  profitLoss                                                 6 non-null      int64
#  57  cashflowFromInvestment                                     6 non-null      int64
#  58  cashflowFromFinancing                                      6 non-null      int64
#  59  paymentsForRepurchaseOfCommonStock                         6 non-null      int64
#  60  paymentsForRepurchaseOfEquity                              6 non-null      int64
#  61  dividendPayout                                             6 non-null      int64
#  62  dividendPayoutCommonStock                                  6 non-null      int64
#  63  proceedsFromIssuanceOfLongTermDebtAndCapitalSecuritiesNet  6 non-null      int64
#  64  proceedsFromRepurchaseOfEquity                             6 non-null      int64
#  65  changeInCashAndCashEquivalents                             6 non-null      int64
#  66  netIncome_y                                                6 non-null      int64
# dtypes: int64(67)
# memory usage: 3.2+ KB

# %%
dfs
# Out:
#                   totalAssets  totalCurrentAssets  \
# fiscalDateEnding
# 2018-09-02        40830000000         20289000000
# 2019-09-01        45400000000         23485000000
# 2020-08-30        55556000000         28120000000
# 2021-08-29        59268000000         29505000000
# 2022-08-28        64166000000         32696000000
# 2023-12-31        64166000000         32696000000
#
#                   cashAndCashEquivalentsAtCarryingValue  \
# fiscalDateEnding
# 2018-09-02                                   6055000000
# 2019-09-01                                   8384000000
# 2020-08-30                                  12277000000
# 2021-08-29                                  11258000000
# 2022-08-28                                  10203000000
# 2023-12-31                                  10203000000
#
#                   cashAndShortTermInvestments    inventory  \
# fiscalDateEnding
# 2018-09-02                         7259000000  11040000000
# 2019-09-01                         9444000000  11395000000
# 2020-08-30                        13305000000  12242000000
# 2021-08-29                        12175000000  14215000000
# 2022-08-28                        11049000000  17907000000
# 2023-12-31                        11049000000  17907000000
#
#                   currentNetReceivables  totalNonCurrentAssets  \
# fiscalDateEnding
# 2018-09-02                   1669000000            20541000000
# 2019-09-01                   1535000000            21915000000
# 2020-08-30                   1550000000            29016000000
# 2021-08-29                   1803000000            30759000000
# 2022-08-28                   2241000000            32463000000
# 2023-12-31                   2241000000            32463000000
#
#                   propertyPlantEquipment  \
# fiscalDateEnding
# 2018-09-02                   19681000000
# 2019-09-01                   20890000000
# 2020-08-30                   21807000000
# 2021-08-29                   23492000000
# 2022-08-28                   24646000000
# 2023-12-31                   24646000000
#
#                   accumulatedDepreciationAmortizationPPE  \
# fiscalDateEnding
# 2018-09-02                                   11033000000
# 2019-09-01                                   11736000000
# 2020-08-30                                   12896000000
# 2021-08-29                                   14166000000
# 2022-08-28                                   15286000000
# 2023-12-31                                   15286000000
#
#                   shortTermInvestments  ...  cashflowFromInvestment  \
# fiscalDateEnding                        ...
# 2018-09-02                  1204000000  ...             -2947000000
# 2019-09-01                  1060000000  ...             -2865000000
# 2020-08-30                  1028000000  ...             -3891000000
# 2021-08-29                   917000000  ...             -3535000000
# 2022-08-28                   846000000  ...             -3915000000
# 2023-12-31                   846000000  ...             -3915000000
#
#                   cashflowFromFinancing  paymentsForRepurchaseOfCommonStock  \
# fiscalDateEnding
# 2018-09-02                  -1281000000                           328000000
# 2019-09-01                  -1147000000                           247000000
# 2020-08-30                  -1147000000                           196000000
# 2021-08-29                  -6488000000                           496000000
# 2022-08-28                  -4283000000                           439000000
# 2023-12-31                  -4283000000                           439000000
#
#                   paymentsForRepurchaseOfEquity  dividendPayout  \
# fiscalDateEnding
# 2018-09-02                            328000000       689000000
# 2019-09-01                            247000000      1038000000
# 2020-08-30                            196000000      1479000000
# 2021-08-29                            496000000      5748000000
# 2022-08-28                                    0      1706000000
# 2023-12-31                                    0      1706000000
#
#                   dividendPayoutCommonStock  \
# fiscalDateEnding
# 2018-09-02                        689000000
# 2019-09-01                       1038000000
# 2020-08-30                       1479000000
# 2021-08-29                       5748000000
# 2022-08-28                       1498000000
# 2023-12-31                       1498000000
#
#                   proceedsFromIssuanceOfLongTermDebtAndCapitalSecuritiesNet  \
# fiscalDateEnding
# 2018-09-02                                                        0
# 2019-09-01                                                298000000
# 2020-08-30                                               3992000000
# 2021-08-29                                                        0
# 2022-08-28                                                        0
# 2023-12-31                                                        0
#
#                   proceedsFromRepurchaseOfEquity  \
# fiscalDateEnding
# 2018-09-02                            -328000000
# 2019-09-01                            -247000000
# 2020-08-30                            -196000000
# 2021-08-29                            -496000000
# 2022-08-28                                     0
# 2023-12-31                                     0
#
#                   changeInCashAndCashEquivalents  netIncome_y
# fiscalDateEnding
# 2018-09-02                            1509000000   3134000000
# 2019-09-01                            2329000000   3659000000
# 2020-08-30                            3893000000   4002000000
# 2021-08-29                           -1019000000   5007000000
# 2022-08-28                            -806000000   5844000000
# 2023-12-31                            -806000000   5844000000
#
# [6 rows x 67 columns]

# %%
scaler = StandardScaler()
data_scaled = scaler.fit_transform(dfs)

ica = picard.Picard( random_state=42, fun='exp')
components = ica.fit_transform(data_scaled)

df_components = pd.DataFrame(components)
seq = ['2018-12-31', '2019-12-31', '2020-12-31', '2021-12-31', '2022-12-31', '2023-12-31']
df_components.insert(0, 'Date', seq)

# %%
df_components
# Out:
#          Date             0             1             2             3  \
# 0  2018-12-31  1.385862e+14  2.043908e+14  6.212892e+13  3.573442e+14
# 1  2019-12-31  1.775146e+14  2.618034e+14  7.958072e+13  4.577210e+14
# 2  2020-12-31 -3.555771e+13 -5.244148e+13 -1.594070e+13 -9.168545e+13
# 3  2021-12-31 -9.211355e+13 -1.358516e+14 -4.129497e+13 -2.375145e+14
# 4  2022-12-31 -3.759507e+14 -5.544624e+14 -1.685406e+14 -9.693878e+14
# 5  2023-12-31 -3.759507e+14 -5.544624e+14 -1.685406e+14 -9.693878e+14
#
#               4             5
# 0  1.128857e+14  3.320616e+14
# 1  1.445949e+14  4.253366e+14
# 2 -2.896361e+13 -8.519857e+13
# 3 -7.503129e+13 -2.207100e+14
# 4 -3.062315e+14 -9.008022e+14
# 5 -3.062315e+14 -9.008022e+14

# %%
df2=df_components
df1=get_columns(stock)
df2=df2.reset_index()
df2.drop(columns=['index'])

df2['Date'] = df2['Date'].apply(lambda x: x[:4])
df1['year'] = pd.to_datetime(df1['Date'], format='%Y-%m-%d').dt.year
df2['year'] = pd.to_datetime(df2['Date']).dt.year.astype(int)

df2.rename(columns={0:"0",1: "1",2:"2",3:"3",4:"4"}, inplace=True)
merged_df = pd.merge(df1, df2, on='year')
merged_df.drop(['Date_y', 'year'], axis=1, inplace=True)

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1369 entries, 0 to 1368
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date_x               1369 non-null   datetime64[ns, America/New_York]
#  1   Open                 1369 non-null   float64
#  2   High                 1369 non-null   float64
#  3   Low                  1369 non-null   float64
#  4   Close                1369 non-null   float64
#  5   Volume               1369 non-null   int64
#  6   Dividends            1369 non-null   float64
#  7   Stock Splits         1369 non-null   float64
#  8   Job_Value            1369 non-null   float64
#  9   Labour_values        1369 non-null   int64
#  10  Manufacturing_Value  1369 non-null   float64
#  11  CPI_Value            1369 non-null   float64
#  12  inflation_Value      1369 non-null   float64
#  13  Housing_value        1369 non-null   float64
#  14  NASDAQCOM            1369 non-null   float64
#  15  index                1369 non-null   int64
#  16  0                    1369 non-null   float64
#  17  1                    1369 non-null   float64
#  18  2                    1369 non-null   float64
#  19  3                    1369 non-null   float64
#  20  4                    1369 non-null   float64
#  21  5                    1369 non-null   float64
# dtypes: datetime64[ns, America/New_York](1), float64(18), int64(3)
# memory usage: 246.0 KB

# %%
url = 'https://eodhistoricaldata.com/api/sentiments?s={}&from=2000-01-01&to=2023-06-30&api_token=6481b11d245909.63698937'.format(stock)
response = requests.get(url)
data = response.json()
ticker = list(data.keys())[0]
sent_df = pd.DataFrame(data[ticker])

# %%
response.json()
# Out:
# {'COST.US': [{'date': '2023-06-10', 'count': 7, 'normalized': 0.4311},
#   {'date': '2023-06-08', 'count': 8, 'normalized': 0.6186},
#   {'date': '2023-06-07', 'count': 1, 'normalized': 0.889},
#   {'date': '2023-06-06', 'count': 6, 'normalized': 0.5995},
#   {'date': '2023-06-05', 'count': 1, 'normalized': 1},
#   {'date': '2023-06-04', 'count': 4, 'normalized': 0.622},
#   {'date': '2023-06-02', 'count': 7, 'normalized': 0.676},
#   {'date': '2023-06-01', 'count': 4, 'normalized': 0.9245},
#   {'date': '2023-05-31', 'count': 8, 'normalized': 0.5483},
#   {'date': '2023-05-30', 'count': 1, 'normalized': 0.687},
#   {'date': '2023-05-29', 'count': 4, 'normalized': 0.9023},
#   {'date': '2023-05-27', 'count': 1, 'normalized': 0.883},
#   {'date': '2023-05-26', 'count': 2, 'normalized': 0.9905},
#   {'date': '2023-05-25', 'count': 1, 'normalized': 0.996},
#   {'date': '2023-05-24', 'count': 1, 'normalized': -0.915},
#   {'date': '2023-05-23', 'count': 1, 'normalized': 0.999},
#   {'date': '2023-05-22', 'count': 4, 'normalized': 0.7335},
#   {'date': '2023-05-21', 'count': 3, 'normalized': 0.0593},
#   {'date': '2023-05-18', 'count': 5, 'normalized': 0.5632},
#   {'date': '2023-05-17', 'count': 11, 'normalized': 0.2016},
#   {'date': '2023-05-16', 'count': 7, 'normalized': 0.626},
#   {'date': '2023-05-14', 'count': 1, 'normalized': 0.992},
#   {'date': '2023-05-12', 'count': 3, 'normalized': 0.748},
#   {'date': '2023-05-10', 'count': 4, 'normalized': 0.9515},
#   {'date': '2023-05-09', 'count': 4, 'normalized': 0.9208},
#   {'date': '2023-05-06', 'count': 1, 'normalized': 0.178},
#   {'date': '2023-05-03', 'count': 6, 'normalized': 0.7578},
#   {'date': '2023-05-02', 'count': 6, 'normalized': 0.997},
#   {'date': '2023-04-27', 'count': 6, 'normalized': 0.6718},
#   {'date': '2023-04-25', 'count': 4, 'normalized': 0.9975},
#   {'date': '2023-04-24', 'count': 9, 'normalized': 0.6141},
#   {'date': '2023-04-23', 'count': 2, 'normalized': 0.6725},
#   {'date': '2023-04-22', 'count': 1, 'normalized': 0.931},
#   {'date': '2023-04-21', 'count': 4, 'normalized': 0.8718},
#   {'date': '2023-04-20', 'count': 5, 'normalized': 0.6834},
#   {'date': '2023-04-19', 'count': 6, 'normalized': 0.6168},
#   {'date': '2023-04-17', 'count': 8, 'normalized': 0.6715},
#   {'date': '2023-04-16', 'count': 1, 'normalized': 1},
#   {'date': '2023-04-14', 'count': 2, 'normalized': 0.6465},
#   {'date': '2023-04-13', 'count': 5, 'normalized': 0.827},
#   {'date': '2023-04-12', 'count': 7, 'normalized': 0.6831},
#   {'date': '2023-04-11', 'count': 3, 'normalized': 0.6663},
#   {'date': '2023-04-10', 'count': 4, 'normalized': 0.7985},
#   {'date': '2023-04-09', 'count': 1, 'normalized': 0.996},
#   {'date': '2023-04-07', 'count': 6, 'normalized': 0.7225},
#   {'date': '2023-04-06', 'count': 23, 'normalized': 0.0844},
#   {'date': '2023-04-05', 'count': 7, 'normalized': 0.5791},
#   {'date': '2023-04-04', 'count': 6, 'normalized': 0.7697},
#   {'date': '2023-04-01', 'count': 1, 'normalized': 0.896},
#   {'date': '2023-03-31', 'count': 1, 'normalized': 0.994},
#   {'date': '2023-03-30', 'count': 6, 'normalized': 0.8332},
#   {'date': '2023-03-29', 'count': 7, 'normalized': 0.7449},
#   {'date': '2023-03-28', 'count': 7, 'normalized': 0.8314},
#   {'date': '2023-03-27', 'count': 4, 'normalized': 0.9945},
#   {'date': '2023-03-26', 'count': 3, 'normalized': 0.6593},
#   {'date': '2023-03-25', 'count': 1, 'normalized': 0.026},
#   {'date': '2023-03-24', 'count': 6, 'normalized': 0.4898},
#   {'date': '2023-03-23', 'count': 2, 'normalized': 0.8235},
#   {'date': '2023-03-22', 'count': 8, 'normalized': 0.5696},
#   {'date': '2023-03-21', 'count': 7, 'normalized': 0.5897},
#   {'date': '2023-03-20', 'count': 8, 'normalized': 0.5849},
#   {'date': '2023-03-19', 'count': 5, 'normalized': 0.435},
#   {'date': '2023-03-18', 'count': 3, 'normalized': 0.2497},
#   {'date': '2023-03-17', 'count': 7, 'normalized': 0.6503},
#   {'date': '2023-03-16', 'count': 4, 'normalized': 0.5208},
#   {'date': '2023-03-15', 'count': 5, 'normalized': 0.6048},
#   {'date': '2023-03-14', 'count': 6, 'normalized': 0.64},
#   {'date': '2023-03-13', 'count': 2, 'normalized': 0.7625},
#   {'date': '2023-03-11', 'count': 3, 'normalized': 0.636},
#   {'date': '2023-03-10', 'count': 11, 'normalized': 0.4469},
#   {'date': '2023-03-09', 'count': 4, 'normalized': 0.277},
#   {'date': '2023-03-08', 'count': 13, 'normalized': 0.406},
#   {'date': '2023-03-07', 'count': 8, 'normalized': 0.7679},
#   {'date': '2023-03-06', 'count': 9, 'normalized': 0.6966},
#   {'date': '2023-03-05', 'count': 2, 'normalized': -0.0025},
#   {'date': '2023-03-04', 'count': 7, 'normalized': 0.6547},
#   {'date': '2023-03-03', 'count': 37, 'normalized': 0.5112},
#   {'date': '2023-03-02', 'count': 28, 'normalized': 0.4627},
#   {'date': '2023-03-01', 'count': 9, 'normalized': 0.4302},
#   {'date': '2023-02-28', 'count': 9, 'normalized': 0.8396},
#   {'date': '2023-02-27', 'count': 7, 'normalized': 0.7334},
#   {'date': '2023-02-26', 'count': 3, 'normalized': 0.934},
#   {'date': '2023-02-25', 'count': 9, 'normalized': 0.6162},
#   {'date': '2023-02-24', 'count': 10, 'normalized': 0.9138},
#   {'date': '2023-02-23', 'count': 10, 'normalized': 0.8717},
#   {'date': '2023-02-22', 'count': 1, 'normalized': 0.999},
#   {'date': '2023-02-21', 'count': 6, 'normalized': 0.7637},
#   {'date': '2023-02-20', 'count': 8, 'normalized': 0.8419},
#   {'date': '2023-02-18', 'count': 2, 'normalized': 0.643},
#   {'date': '2023-02-17', 'count': 5, 'normalized': 0.7764},
#   {'date': '2023-02-16', 'count': 12, 'normalized': 0.5894},
#   {'date': '2023-02-15', 'count': 3, 'normalized': 0.995},
#   {'date': '2023-02-14', 'count': 4, 'normalized': 0.9015},
#   {'date': '2023-02-13', 'count': 4, 'normalized': 0.796},
#   {'date': '2023-02-12', 'count': 2, 'normalized': 0.5035},
#   {'date': '2023-02-11', 'count': 2, 'normalized': 0.849},
#   {'date': '2023-02-10', 'count': 6, 'normalized': 0.4183},
#   {'date': '2023-02-09', 'count': 4, 'normalized': 0.588},
#   {'date': '2023-02-08', 'count': 8, 'normalized': 0.7811},
#   {'date': '2023-02-07', 'count': 6, 'normalized': 0.8833},
#   {'date': '2023-02-06', 'count': 9, 'normalized': 0.9073},
#   {'date': '2023-02-05', 'count': 5, 'normalized': 0.2274},
#   {'date': '2023-02-04', 'count': 1, 'normalized': -0.653},
#   {'date': '2023-02-03', 'count': 4, 'normalized': 0.7748},
#   {'date': '2023-02-02', 'count': 10, 'normalized': 0.7319},
#   {'date': '2023-02-01', 'count': 10, 'normalized': 0.7279},
#   {'date': '2023-01-31', 'count': 4, 'normalized': 0.4715},
#   {'date': '2023-01-30', 'count': 8, 'normalized': 0.7595},
#   {'date': '2023-01-29', 'count': 3, 'normalized': 0.409},
#   {'date': '2023-01-28', 'count': 2, 'normalized': 0.526},
#   {'date': '2023-01-27', 'count': 3, 'normalized': 0.7713},
#   {'date': '2023-01-26', 'count': 8, 'normalized': 0.5349},
#   {'date': '2023-01-25', 'count': 4, 'normalized': 0.8213},
#   {'date': '2023-01-24', 'count': 5, 'normalized': 0.8966},
#   {'date': '2023-01-23', 'count': 5, 'normalized': 0.9062},
#   {'date': '2023-01-22', 'count': 1, 'normalized': 0},
#   {'date': '2023-01-21', 'count': 3, 'normalized': 0.709},
#   {'date': '2023-01-20', 'count': 7, 'normalized': 0.7121},
#   {'date': '2023-01-19', 'count': 11, 'normalized': 0.5979},
#   {'date': '2023-01-18', 'count': 9, 'normalized': 0.7118},
#   {'date': '2023-01-17', 'count': 6, 'normalized': 0.3063},
#   {'date': '2023-01-16', 'count': 2, 'normalized': 0.3825},
#   {'date': '2023-01-15', 'count': 2, 'normalized': -0.0735},
#   {'date': '2023-01-14', 'count': 1, 'normalized': 1},
#   {'date': '2023-01-13', 'count': 3, 'normalized': 0.9983},
#   {'date': '2023-01-12', 'count': 1, 'normalized': 0.996},
#   {'date': '2023-01-11', 'count': 4, 'normalized': 0.9673},
#   {'date': '2023-01-10', 'count': 8, 'normalized': 0.788},
#   {'date': '2023-01-09', 'count': 11, 'normalized': 0.6075},
#   {'date': '2023-01-08', 'count': 2, 'normalized': 0.88},
#   {'date': '2023-01-07', 'count': 5, 'normalized': 0.9108},
#   {'date': '2023-01-06', 'count': 13, 'normalized': 0.8223},
#   {'date': '2023-01-05', 'count': 9, 'normalized': 0.6363},
#   {'date': '2023-01-04', 'count': 1, 'normalized': 0.599},
#   {'date': '2023-01-03', 'count': 6, 'normalized': 0.2858},
#   {'date': '2023-01-02', 'count': 1, 'normalized': 0},
#   {'date': '2023-01-01', 'count': 2, 'normalized': 0.2465},
#   {'date': '2022-12-31', 'count': 3, 'normalized': 0.7667},
#   {'date': '2022-12-30', 'count': 7, 'normalized': 0.8669},
#   {'date': '2022-12-29', 'count': 8, 'normalized': 0.7298},
#   {'date': '2022-12-28', 'count': 4, 'normalized': 0.868},
#   {'date': '2022-12-27', 'count': 1, 'normalized': 0.71},
#   {'date': '2022-12-26', 'count': 2, 'normalized': 0.999},
#   {'date': '2022-12-24', 'count': 2, 'normalized': 0.8745},
#   {'date': '2022-12-23', 'count': 7, 'normalized': 0.5806},
#   {'date': '2022-12-22', 'count': 4, 'normalized': 0.7798},
#   {'date': '2022-12-21', 'count': 3, 'normalized': 0.5203},
#   {'date': '2022-12-20', 'count': 4, 'normalized': 0.9528},
#   {'date': '2022-12-19', 'count': 4, 'normalized': 0.654},
#   {'date': '2022-12-18', 'count': 4, 'normalized': 0.9363},
#   {'date': '2022-12-17', 'count': 5, 'normalized': 0.5412},
#   {'date': '2022-12-16', 'count': 5, 'normalized': 0.7932},
#   {'date': '2022-12-15', 'count': 6, 'normalized': 0.3925},
#   {'date': '2022-12-14', 'count': 6, 'normalized': 0.8563},
#   {'date': '2022-12-13', 'count': 11, 'normalized': 0.751},
#   {'date': '2022-12-12', 'count': 4, 'normalized': 0.8353},
#   {'date': '2022-12-11', 'count': 2, 'normalized': 0.7485},
#   {'date': '2022-12-10', 'count': 4, 'normalized': 0.8215},
#   {'date': '2022-12-09', 'count': 24, 'normalized': 0.4442},
#   {'date': '2022-12-08', 'count': 22, 'normalized': 0.1188},
#   {'date': '2022-12-07', 'count': 15, 'normalized': 0.5978},
#   {'date': '2022-12-06', 'count': 13, 'normalized': 0.8297},
#   {'date': '2022-12-05', 'count': 19, 'normalized': 0.6932},
#   {'date': '2022-12-04', 'count': 6, 'normalized': 0.6403},
#   {'date': '2022-12-03', 'count': 2, 'normalized': 0.885},
#   {'date': '2022-12-02', 'count': 8, 'normalized': 0.6181},
#   {'date': '2022-12-01', 'count': 22, 'normalized': 0.3455},
#   {'date': '2022-11-30', 'count': 6, 'normalized': 0.6998},
#   {'date': '2022-11-29', 'count': 10, 'normalized': 0.6887},
#   {'date': '2022-11-28', 'count': 4, 'normalized': 0.992},
#   {'date': '2022-11-27', 'count': 3, 'normalized': 0.825},
#   {'date': '2022-11-26', 'count': 5, 'normalized': 0.7614},
#   {'date': '2022-11-25', 'count': 4, 'normalized': 0.7878},
#   {'date': '2022-11-24', 'count': 3, 'normalized': 0.9987},
#   {'date': '2022-11-23', 'count': 5, 'normalized': 0.579},
#   {'date': '2022-11-22', 'count': 8, 'normalized': 0.8298},
#   {'date': '2022-11-21', 'count': 12, 'normalized': 0.9353},
#   {'date': '2022-11-20', 'count': 3, 'normalized': 0.596},
#   {'date': '2022-11-19', 'count': 2, 'normalized': 0.9985},
#   {'date': '2022-11-18', 'count': 10, 'normalized': 0.9106},
#   {'date': '2022-11-17', 'count': 9, 'normalized': 0.8621},
#   {'date': '2022-11-16', 'count': 12, 'normalized': 0.3792},
#   {'date': '2022-11-15', 'count': 10, 'normalized': 0.5651},
#   {'date': '2022-11-14', 'count': 5, 'normalized': 0.8614},
#   {'date': '2022-11-13', 'count': 2, 'normalized': 0.6545},
#   {'date': '2022-11-12', 'count': 3, 'normalized': 0.464},
#   {'date': '2022-11-11', 'count': 3, 'normalized': 0.7713},
#   {'date': '2022-11-10', 'count': 6, 'normalized': 0.6008},
#   {'date': '2022-11-09', 'count': 2, 'normalized': 0.4485},
#   {'date': '2022-11-08', 'count': 1, 'normalized': 0.961},
#   {'date': '2022-11-07', 'count': 11, 'normalized': 0.5133},
#   {'date': '2022-11-06', 'count': 3, 'normalized': 0.9747},
#   {'date': '2022-11-05', 'count': 1, 'normalized': 0.796},
#   {'date': '2022-11-04', 'count': 2, 'normalized': 0.4315},
#   {'date': '2022-11-03', 'count': 4, 'normalized': 0.5663},
#   {'date': '2022-11-02', 'count': 8, 'normalized': 0.7591},
#   {'date': '2022-11-01', 'count': 2, 'normalized': 0.5},
#   {'date': '2022-10-31', 'count': 5, 'normalized': 0.5878},
#   {'date': '2022-10-30', 'count': 3, 'normalized': 0.5617},
#   {'date': '2022-10-29', 'count': 2, 'normalized': 0.84},
#   {'date': '2022-10-28', 'count': 4, 'normalized': 0.4883},
#   {'date': '2022-10-27', 'count': 3, 'normalized': 0.8897},
#   {'date': '2022-10-25', 'count': 5, 'normalized': 0.7644},
#   {'date': '2022-10-24', 'count': 2, 'normalized': 0.5},
#   {'date': '2022-10-22', 'count': 3, 'normalized': 0.637},
#   {'date': '2022-10-21', 'count': 4, 'normalized': 0.7818},
#   {'date': '2022-10-20', 'count': 5, 'normalized': 0.612},
#   {'date': '2022-10-19', 'count': 4, 'normalized': 0.493},
#   {'date': '2022-10-18', 'count': 5, 'normalized': 0.6882},
#   {'date': '2022-10-17', 'count': 3, 'normalized': 0.3077},
#   {'date': '2022-10-16', 'count': 2, 'normalized': 0.7965},
#   {'date': '2022-10-15', 'count': 4, 'normalized': 0.0658},
#   {'date': '2022-10-14', 'count': 5, 'normalized': 0.7068},
#   {'date': '2022-10-13', 'count': 3, 'normalized': 0.6233},
#   {'date': '2022-10-12', 'count': 9, 'normalized': 0.4471},
#   {'date': '2022-10-11', 'count': 7, 'normalized': 0.6104},
#   {'date': '2022-10-10', 'count': 4, 'normalized': 0.4033},
#   {'date': '2022-10-09', 'count': 6, 'normalized': 0.338},
#   {'date': '2022-10-08', 'count': 3, 'normalized': 0.5877},
#   {'date': '2022-10-07', 'count': 7, 'normalized': 0.5296},
#   {'date': '2022-10-06', 'count': 6, 'normalized': -0.0475},
#   {'date': '2022-10-05', 'count': 13, 'normalized': 0.3834},
#   {'date': '2022-10-04', 'count': 3, 'normalized': 0.261},
#   {'date': '2022-10-03', 'count': 3, 'normalized': 0.8003},
#   {'date': '2022-10-02', 'count': 1, 'normalized': 0.214},
#   {'date': '2022-10-01', 'count': 4, 'normalized': 0.8558},
#   {'date': '2022-09-30', 'count': 5, 'normalized': 0.5846},
#   {'date': '2022-09-29', 'count': 1, 'normalized': 0.836},
#   {'date': '2022-09-28', 'count': 5, 'normalized': 0.8846},
#   {'date': '2022-09-27', 'count': 5, 'normalized': 0.387},
#   {'date': '2022-09-26', 'count': 4, 'normalized': 0.8043},
#   {'date': '2022-09-25', 'count': 4, 'normalized': 0.837},
#   {'date': '2022-09-24', 'count': 1, 'normalized': 0.042},
#   {'date': '2022-09-23', 'count': 36, 'normalized': 0.0507},
#   {'date': '2022-09-22', 'count': 31, 'normalized': 0.3834},
#   {'date': '2022-09-21', 'count': 6, 'normalized': 0.487},
#   {'date': '2022-09-20', 'count': 5, 'normalized': 0.9236},
#   {'date': '2022-09-19', 'count': 4, 'normalized': 0.634},
#   {'date': '2022-09-18', 'count': 4, 'normalized': 0.3268},
#   {'date': '2022-09-17', 'count': 2, 'normalized': 0.909},
#   {'date': '2022-09-16', 'count': 5, 'normalized': 0.084},
#   {'date': '2022-09-15', 'count': 7, 'normalized': 0.7261},
#   {'date': '2022-09-14', 'count': 4, 'normalized': 0.4388},
#   {'date': '2022-09-13', 'count': 3, 'normalized': 0.6657},
#   {'date': '2022-09-12', 'count': 2, 'normalized': 0.6495},
#   {'date': '2022-09-11', 'count': 1, 'normalized': 0.671},
#   {'date': '2022-09-10', 'count': 1, 'normalized': -0.868},
#   {'date': '2022-09-09', 'count': 1, 'normalized': 0},
#   {'date': '2022-09-08', 'count': 6, 'normalized': 0.483},
#   {'date': '2022-09-07', 'count': 3, 'normalized': 0.4457},
#   {'date': '2022-09-06', 'count': 3, 'normalized': 0.1183},
#   {'date': '2022-09-05', 'count': 3, 'normalized': 0.877},
#   {'date': '2022-09-02', 'count': 6, 'normalized': 0.4675},
#   {'date': '2022-09-01', 'count': 6, 'normalized': 0.613},
#   {'date': '2022-08-31', 'count': 7, 'normalized': 0.1363},
#   {'date': '2022-08-30', 'count': 3, 'normalized': 0.7953},
#   {'date': '2022-08-29', 'count': 7, 'normalized': 0.3243},
#   {'date': '2022-08-27', 'count': 4, 'normalized': 0.479},
#   {'date': '2022-08-26', 'count': 6, 'normalized': 0.8012},
#   {'date': '2022-08-25', 'count': 1, 'normalized': 0.772},
#   {'date': '2022-08-24', 'count': 3, 'normalized': 0.5367},
#   {'date': '2022-08-23', 'count': 4, 'normalized': 0.3843},
#   {'date': '2022-08-22', 'count': 7, 'normalized': 0.4466},
#   {'date': '2022-08-20', 'count': 2, 'normalized': 0.246},
#   {'date': '2022-08-19', 'count': 2, 'normalized': 0},
#   {'date': '2022-08-18', 'count': 9, 'normalized': 0.4463},
#   {'date': '2022-08-17', 'count': 6, 'normalized': 0.2502},
#   {'date': '2022-08-16', 'count': 11, 'normalized': 0.2945},
#   {'date': '2022-08-15', 'count': 6, 'normalized': 0.5038},
#   {'date': '2022-08-13', 'count': 1, 'normalized': 0},
#   {'date': '2022-08-12', 'count': 3, 'normalized': 0.9983},
#   {'date': '2022-08-11', 'count': 5, 'normalized': 0.6604},
#   {'date': '2022-08-10', 'count': 3, 'normalized': 0.9963},
#   {'date': '2022-08-09', 'count': 5, 'normalized': 0.8502},
#   {'date': '2022-08-08', 'count': 1, 'normalized': 0.999},
#   {'date': '2022-08-07', 'count': 4, 'normalized': 0.2388},
#   {'date': '2022-08-06', 'count': 1, 'normalized': 0.93},
#   {'date': '2022-08-05', 'count': 2, 'normalized': 0.623},
#   {'date': '2022-08-04', 'count': 7, 'normalized': 0.5364},
#   {'date': '2022-08-03', 'count': 3, 'normalized': -0.008},
#   {'date': '2022-08-02', 'count': 1, 'normalized': -0.042},
#   {'date': '2022-08-01', 'count': 3, 'normalized': 0.4797},
#   {'date': '2022-07-31', 'count': 1, 'normalized': 0.903},
#   {'date': '2022-07-29', 'count': 1, 'normalized': 0.994},
#   {'date': '2022-07-28', 'count': 5, 'normalized': 0.5204},
#   {'date': '2022-07-27', 'count': 5, 'normalized': 0.3844},
#   {'date': '2022-07-26', 'count': 9, 'normalized': 0.3194},
#   {'date': '2022-07-25', 'count': 2, 'normalized': 0.9105},
#   {'date': '2022-07-23', 'count': 3, 'normalized': 0.343},
#   {'date': '2022-07-22', 'count': 1, 'normalized': 1},
#   {'date': '2022-07-21', 'count': 3, 'normalized': 0.6657},
#   {'date': '2022-07-20', 'count': 1, 'normalized': 0},
#   {'date': '2022-07-19', 'count': 3, 'normalized': 0.753},
#   {'date': '2022-07-18', 'count': 2, 'normalized': 0.1365},
#   {'date': '2022-07-17', 'count': 4, 'normalized': 0.3608},
#   {'date': '2022-07-16', 'count': 1, 'normalized': 0},
#   {'date': '2022-07-15', 'count': 6, 'normalized': 0.4923},
#   {'date': '2022-07-14', 'count': 15, 'normalized': 0.4967},
#   {'date': '2022-07-13', 'count': 4, 'normalized': -0.3748},
#   {'date': '2022-07-12', 'count': 3, 'normalized': 0.5437},
#   {'date': '2022-07-11', 'count': 6, 'normalized': 0.5128},
#   {'date': '2022-07-10', 'count': 1, 'normalized': 0.625},
#   {'date': '2022-07-09', 'count': 3, 'normalized': 0.481},
#   {'date': '2022-07-08', 'count': 9, 'normalized': 0.6553},
#   {'date': '2022-07-07', 'count': 3, 'normalized': -0.3407},
#   {'date': '2022-07-06', 'count': 3, 'normalized': 0.5743},
#   {'date': '2022-07-05', 'count': 7, 'normalized': 0.4336},
#   {'date': '2022-07-04', 'count': 4, 'normalized': 0.5173},
#   {'date': '2022-07-03', 'count': 1, 'normalized': 0},
#   {'date': '2022-07-01', 'count': 5, 'normalized': 0.4002},
#   {'date': '2022-06-30', 'count': 6, 'normalized': 0.2008},
#   {'date': '2022-06-29', 'count': 2, 'normalized': 0.423},
#   {'date': '2022-06-28', 'count': 3, 'normalized': -0.0353},
#   {'date': '2022-06-27', 'count': 3, 'normalized': 0.4183},
#   {'date': '2022-06-25', 'count': 2, 'normalized': -0.2495},
#   {'date': '2022-06-24', 'count': 2, 'normalized': 0.9995},
#   {'date': '2022-06-23', 'count': 3, 'normalized': 0.8943},
#   {'date': '2022-06-22', 'count': 2, 'normalized': 0.999},
#   {'date': '2022-06-21', 'count': 4, 'normalized': 0.7368},
#   {'date': '2022-06-19', 'count': 3, 'normalized': 0.247},
#   {'date': '2022-06-18', 'count': 3, 'normalized': -0.21},
#   {'date': '2022-06-17', 'count': 1, 'normalized': 0},
#   {'date': '2022-06-16', 'count': 2, 'normalized': -0.332},
#   {'date': '2022-06-15', 'count': 4, 'normalized': 0.4318},
#   {'date': '2022-06-14', 'count': 2, 'normalized': 0.964},
#   {'date': '2022-06-13', 'count': 8, 'normalized': 0.6569},
#   {'date': '2022-06-12', 'count': 3, 'normalized': 0.2787},
#   {'date': '2022-06-11', 'count': 1, 'normalized': -0.094},
#   {'date': '2022-06-10', 'count': 6, 'normalized': 0.8327},
#   {'date': '2022-06-09', 'count': 5, 'normalized': 0.629},
#   {'date': '2022-06-08', 'count': 5, 'normalized': 0.5608},
#   {'date': '2022-06-07', 'count': 9, 'normalized': 0.2279},
#   {'date': '2022-06-06', 'count': 4, 'normalized': 0.7058},
#   {'date': '2022-06-04', 'count': 3, 'normalized': 0.355},
#   {'date': '2022-06-03', 'count': 7, 'normalized': 0.6353},
#   {'date': '2022-06-02', 'count': 7, 'normalized': 0.1729},
#   {'date': '2022-06-01', 'count': 2, 'normalized': 0.494},
#   {'date': '2022-05-31', 'count': 6, 'normalized': 0.6063},
#   {'date': '2022-05-30', 'count': 4, 'normalized': 0.4575},
#   {'date': '2022-05-29', 'count': 2, 'normalized': 0.5435},
#   {'date': '2022-05-28', 'count': 1, 'normalized': 0.557},
#   {'date': '2022-05-27', 'count': 16, 'normalized': 0.301},
#   {'date': '2022-05-26', 'count': 13, 'normalized': 0.6038},
#   {'date': '2022-05-25', 'count': 9, 'normalized': 0.055},
#   {'date': '2022-05-24', 'count': 6, 'normalized': 0.6608},
#   {'date': '2022-05-23', 'count': 9, 'normalized': 0.7688},
#   {'date': '2022-05-22', 'count': 3, 'normalized': -0.5787},
#   {'date': '2022-05-21', 'count': 2, 'normalized': 0.468},
#   {'date': '2022-05-20', 'count': 6, 'normalized': 0.1358},
#   {'date': '2022-05-19', 'count': 17, 'normalized': 0.7709},
#   {'date': '2022-05-18', 'count': 11, 'normalized': 0.2896},
#   {'date': '2022-05-17', 'count': 6, 'normalized': 0.7725},
#   {'date': '2022-05-16', 'count': 10, 'normalized': 0.9529},
#   {'date': '2022-05-15', 'count': 3, 'normalized': 0.5143},
#   {'date': '2022-05-14', 'count': 5, 'normalized': -0.1886},
#   {'date': '2022-05-13', 'count': 5, 'normalized': 0.9722},
#   {'date': '2022-05-12', 'count': 5, 'normalized': 0.7972},
#   {'date': '2022-05-11', 'count': 4, 'normalized': 0.999},
#   {'date': '2022-05-10', 'count': 5, 'normalized': 0.9638},
#   {'date': '2022-05-09', 'count': 3, 'normalized': 0.8427},
#   {'date': '2022-05-08', 'count': 1, 'normalized': 0.633},
#   {'date': '2022-05-06', 'count': 6, 'normalized': 0.9352},
#   {'date': '2022-05-05', 'count': 11, 'normalized': 0.4835},
#   {'date': '2022-05-04', 'count': 5, 'normalized': 0.2806},
#   {'date': '2022-05-03', 'count': 6, 'normalized': 0.7335},
#   {'date': '2022-05-02', 'count': 6, 'normalized': 0.8617},
#   {'date': '2022-05-01', 'count': 1, 'normalized': 0.999},
#   {'date': '2022-04-30', 'count': 2, 'normalized': 0.85},
#   {'date': '2022-04-29', 'count': 4, 'normalized': 0.307},
#   {'date': '2022-04-28', 'count': 4, 'normalized': 0.688},
#   {'date': '2022-04-27', 'count': 4, 'normalized': 0.8563},
#   {'date': '2022-04-26', 'count': 5, 'normalized': 0.7134},
#   {'date': '2022-04-25', 'count': 4, 'normalized': 0.9903},
#   {'date': '2022-04-22', 'count': 4, 'normalized': 0.7855},
#   {'date': '2022-04-21', 'count': 1, 'normalized': 0.994},
#   {'date': '2022-04-20', 'count': 7, 'normalized': 0.6259},
#   {'date': '2022-04-19', 'count': 4, 'normalized': 0.9435},
#   {'date': '2022-04-18', 'count': 7, 'normalized': 0.6701},
#   {'date': '2022-04-17', 'count': 2, 'normalized': 0.838},
#   {'date': '2022-04-16', 'count': 1, 'normalized': 0.878},
#   {'date': '2022-04-15', 'count': 6, 'normalized': 0.5505},
#   {'date': '2022-04-14', 'count': 11, 'normalized': 0.7333},
#   {'date': '2022-04-13', 'count': 8, 'normalized': 0.4754},
#   {'date': '2022-04-12', 'count': 1, 'normalized': 0.178},
#   {'date': '2022-04-11', 'count': 6, 'normalized': 0.8053},
#   {'date': '2022-04-08', 'count': 10, 'normalized': 0.7308},
#   {'date': '2022-04-07', 'count': 14, 'normalized': 0.7479},
#   {'date': '2022-04-06', 'count': 6, 'normalized': 0.4552},
#   {'date': '2022-04-05', 'count': 3, 'normalized': 0.785},
#   {'date': '2022-04-04', 'count': 6, 'normalized': 0.7378},
#   {'date': '2022-04-03', 'count': 2, 'normalized': 0.688},
#   {'date': '2022-04-01', 'count': 8, 'normalized': 0.6226},
#   {'date': '2022-03-31', 'count': 6, 'normalized': 0.3622},
#   {'date': '2022-03-30', 'count': 9, 'normalized': 0.1784},
#   {'date': '2022-03-29', 'count': 8, 'normalized': 0.6201},
#   {'date': '2022-03-28', 'count': 6, 'normalized': 0.2627},
#   {'date': '2022-03-25', 'count': 4, 'normalized': 0.8253},
#   {'date': '2022-03-24', 'count': 5, 'normalized': 0.891},
#   {'date': '2022-03-23', 'count': 4, 'normalized': 0.831},
#   {'date': '2022-03-22', 'count': 2, 'normalized': 0.4995},
#   {'date': '2022-03-21', 'count': 6, 'normalized': 0.5952},
#   {'date': '2022-03-19', 'count': 2, 'normalized': 0.6585},
#   {'date': '2022-03-18', 'count': 6, 'normalized': 0.8285},
#   {'date': '2022-03-17', 'count': 4, 'normalized': 0.1133},
#   {'date': '2022-03-16', 'count': 5, 'normalized': 0.469},
#   {'date': '2022-03-15', 'count': 6, 'normalized': 0.4195},
#   {'date': '2022-03-14', 'count': 5, 'normalized': 0.6226},
#   {'date': '2022-03-13', 'count': 1, 'normalized': 0.077},
#   {'date': '2022-03-12', 'count': 4, 'normalized': 0.4538},
#   {'date': '2022-03-11', 'count': 3, 'normalized': 0.2237},
#   {'date': '2022-03-10', 'count': 8, 'normalized': 0.322},
#   {'date': '2022-03-09', 'count': 8, 'normalized': 0.4759},
#   {'date': '2022-03-08', 'count': 13, 'normalized': 0.0955},
#   {'date': '2022-03-07', 'count': 13, 'normalized': 0.3627},
#   {'date': '2022-03-06', 'count': 3, 'normalized': -0.1577},
#   {'date': '2022-03-04', 'count': 18, 'normalized': 0.3104},
#   {'date': '2022-03-03', 'count': 15, 'normalized': 0.4601},
#   {'date': '2022-03-02', 'count': 6, 'normalized': 0.6305},
#   {'date': '2022-03-01', 'count': 7, 'normalized': 0.6884},
#   {'date': '2022-02-28', 'count': 8, 'normalized': 0.8506},
#   {'date': '2022-02-27', 'count': 2, 'normalized': 0.812},
#   {'date': '2022-02-25', 'count': 2, 'normalized': 0.738},
#   {'date': '2022-02-24', 'count': 1, 'normalized': 0.998},
#   {'date': '2022-02-23', 'count': 2, 'normalized': 0.9935},
#   {'date': '2022-02-22', 'count': 4, 'normalized': 0.9815},
#   {'date': '2022-02-21', 'count': 1, 'normalized': 0.999},
#   {'date': '2022-02-18', 'count': 2, 'normalized': 0.9975},
#   {'date': '2022-02-17', 'count': 9, 'normalized': 0.7697},
#   {'date': '2022-02-16', 'count': 8, 'normalized': 0.4959},
#   {'date': '2022-02-15', 'count': 3, 'normalized': 0.7373},
#   {'date': '2022-02-14', 'count': 2, 'normalized': 0.755},
#   {'date': '2022-02-13', 'count': 1, 'normalized': 0.999},
#   {'date': '2022-02-11', 'count': 2, 'normalized': 0.998},
#   {'date': '2022-02-10', 'count': 7, 'normalized': 0.3971},
#   {'date': '2022-02-09', 'count': 4, 'normalized': 0.4968},
#   {'date': '2022-02-08', 'count': 13, 'normalized': 0.8994},
#   {'date': '2022-02-07', 'count': 13, 'normalized': 0.7489},
#   {'date': '2022-02-06', 'count': 1, 'normalized': 1},
#   {'date': '2022-02-05', 'count': 2, 'normalized': 0.423},
#   {'date': '2022-02-04', 'count': 3, 'normalized': 0.6137},
#   {'date': '2022-02-03', 'count': 7, 'normalized': 0.5516},
#   {'date': '2022-02-02', 'count': 13, 'normalized': 0.7982},
#   {'date': '2022-02-01', 'count': 8, 'normalized': 0.8375},
#   {'date': '2022-01-31', 'count': 9, 'normalized': 0.8073},
#   {'date': '2022-01-28', 'count': 7, 'normalized': 0.9843},
#   {'date': '2022-01-27', 'count': 8, 'normalized': 0.9594},
#   {'date': '2022-01-26', 'count': 6, 'normalized': 0.6853},
#   {'date': '2022-01-25', 'count': 6, 'normalized': 0.9573},
#   {'date': '2022-01-24', 'count': 9, 'normalized': 0.9958},
#   {'date': '2022-01-22', 'count': 1, 'normalized': 0.599},
#   {'date': '2022-01-21', 'count': 10, 'normalized': 0.8798},
#   {'date': '2022-01-20', 'count': 5, 'normalized': 0.4124},
#   {'date': '2022-01-19', 'count': 5, 'normalized': 0.9954},
#   {'date': '2022-01-18', 'count': 10, 'normalized': 0.9357},
#   {'date': '2022-01-17', 'count': 2, 'normalized': 0.9995},
#   {'date': '2022-01-15', 'count': 1, 'normalized': 0.836},
#   {'date': '2022-01-14', 'count': 6, 'normalized': 0.7392},
#   {'date': '2022-01-13', 'count': 5, 'normalized': 0.533},
#   {'date': '2022-01-12', 'count': 9, 'normalized': 0.5387},
#   {'date': '2022-01-11', 'count': 4, 'normalized': 0.7355},
#   {'date': '2022-01-10', 'count': 4, 'normalized': 0.8495},
#   {'date': '2022-01-09', 'count': 1, 'normalized': 0.96},
#   {'date': '2022-01-07', 'count': 4, 'normalized': 0.788},
#   {'date': '2022-01-06', 'count': 10, 'normalized': 0.7912},
#   {'date': '2022-01-05', 'count': 9, 'normalized': 0.5227},
#   {'date': '2022-01-04', 'count': 4, 'normalized': 0.685},
#   {'date': '2022-01-03', 'count': 3, 'normalized': 0.8003},
#   {'date': '2022-01-02', 'count': 2, 'normalized': 0.5},
#   {'date': '2021-12-30', 'count': 6, 'normalized': 0.7605},
#   {'date': '2021-12-29', 'count': 4, 'normalized': 0.7538},
#   {'date': '2021-12-28', 'count': 7, 'normalized': 0.5444},
#   {'date': '2021-12-27', 'count': 4, 'normalized': 0.996},
#   {'date': '2021-12-24', 'count': 1, 'normalized': 1},
#   {'date': '2021-12-23', 'count': 4, 'normalized': 0.7565},
#   {'date': '2021-12-22', 'count': 2, 'normalized': 0.172},
#   {'date': '2021-12-21', 'count': 6, 'normalized': 0.6578},
#   {'date': '2021-12-20', 'count': 6, 'normalized': 0.8147},
#   {'date': '2021-12-18', 'count': 2, 'normalized': 0.9995},
#   {'date': '2021-12-17', 'count': 6, 'normalized': 0.886},
#   {'date': '2021-12-16', 'count': 7, 'normalized': 0.8561},
#   {'date': '2021-12-15', 'count': 5, 'normalized': 0.8372},
#   {'date': '2021-12-14', 'count': 7, 'normalized': 0.8139},
#   {'date': '2021-12-13', 'count': 7, 'normalized': 0.6819},
#   {'date': '2021-12-11', 'count': 1, 'normalized': 0},
#   {'date': '2021-12-10', 'count': 21, 'normalized': 0.4481},
#   {'date': '2021-12-09', 'count': 18, 'normalized': 0.59},
#   {'date': '2021-12-08', 'count': 6, 'normalized': 0.6962},
#   {'date': '2021-12-07', 'count': 8, 'normalized': 0.9974},
#   {'date': '2021-12-06', 'count': 4, 'normalized': 0.7838},
#   {'date': '2021-12-05', 'count': 3, 'normalized': 0.6403},
#   {'date': '2021-12-04', 'count': 1, 'normalized': 0.71},
#   {'date': '2021-12-03', 'count': 2, 'normalized': 0.4995},
#   {'date': '2021-12-02', 'count': 5, 'normalized': 0.5228},
#   {'date': '2021-12-01', 'count': 7, 'normalized': 0.4413},
#   {'date': '2021-11-30', 'count': 1, 'normalized': -0.7},
#   {'date': '2021-11-29', 'count': 7, 'normalized': 0.57},
#   {'date': '2021-11-26', 'count': 4, 'normalized': 0.3645},
#   {'date': '2021-11-24', 'count': 6, 'normalized': 0.9842},
#   {'date': '2021-11-23', 'count': 13, 'normalized': 0.6014},
#   {'date': '2021-11-22', 'count': 9, 'normalized': 0.9303},
#   {'date': '2021-11-21', 'count': 1, 'normalized': 0.863},
#   {'date': '2021-11-19', 'count': 8, 'normalized': 0.847},
#   {'date': '2021-11-18', 'count': 8, 'normalized': 0.6696},
#   {'date': '2021-11-17', 'count': 9, 'normalized': 0.609},
#   {'date': '2021-11-16', 'count': 7, 'normalized': 0.5901},
#   {'date': '2021-11-15', 'count': 4, 'normalized': 0.9958},
#   {'date': '2021-11-12', 'count': 3, 'normalized': 0.9133},
#   {'date': '2021-11-10', 'count': 1, 'normalized': 0.992},
#   {'date': '2021-11-09', 'count': 4, 'normalized': 0.5968},
#   {'date': '2021-11-08', 'count': 7, 'normalized': 0.9924},
#   {'date': '2021-11-07', 'count': 1, 'normalized': -0.34},
#   {'date': '2021-11-06', 'count': 1, 'normalized': 0.361},
#   {'date': '2021-11-05', 'count': 3, 'normalized': 0.907},
#   {'date': '2021-11-04', 'count': 11, 'normalized': 0.8793},
#   {'date': '2021-11-03', 'count': 3, 'normalized': 0.119},
#   {'date': '2021-11-02', 'count': 4, 'normalized': 0.6893},
#   {'date': '2021-11-01', 'count': 3, 'normalized': 0.736},
#   {'date': '2021-10-31', 'count': 3, 'normalized': 0.9967},
#   {'date': '2021-10-28', 'count': 3, 'normalized': 0.6913},
#   {'date': '2021-10-27', 'count': 2, 'normalized': 0.995},
#   {'date': '2021-10-26', 'count': 4, 'normalized': 0.653},
#   {'date': '2021-10-25', 'count': 2, 'normalized': 0.991},
#   {'date': '2021-10-24', 'count': 1, 'normalized': 0},
#   {'date': '2021-10-23', 'count': 4, 'normalized': 0.6175},
#   {'date': '2021-10-22', 'count': 1, 'normalized': 0.999},
#   {'date': '2021-10-21', 'count': 3, 'normalized': 0.375},
#   {'date': '2021-10-20', 'count': 2, 'normalized': 0.931},
#   {'date': '2021-10-18', 'count': 1, 'normalized': 0.273},
#   {'date': '2021-10-16', 'count': 3, 'normalized': 0.5993},
#   {'date': '2021-10-15', 'count': 4, 'normalized': 0.7193},
#   {'date': '2021-10-13', 'count': 4, 'normalized': -0.5865},
#   {'date': '2021-10-12', 'count': 2, 'normalized': 0.9275},
#   {'date': '2021-10-11', 'count': 2, 'normalized': 0.2815},
#   {'date': '2021-10-10', 'count': 1, 'normalized': 0.402},
#   {'date': '2021-10-09', 'count': 1, 'normalized': 0.992},
#   {'date': '2021-10-08', 'count': 2, 'normalized': 0.9935},
#   {'date': '2021-10-07', 'count': 6, 'normalized': 0.293},
#   {'date': '2021-10-06', 'count': 3, 'normalized': -0.2977},
#   {'date': '2021-10-05', 'count': 1, 'normalized': 0.897},
#   {'date': '2021-10-04', 'count': 7, 'normalized': 0.9954},
#   {'date': '2021-10-02', 'count': 2, 'normalized': 0.549},
#   {'date': '2021-10-01', 'count': 3, 'normalized': 0.5247},
#   {'date': '2021-09-30', 'count': 3, 'normalized': 0.4237},
#   {'date': '2021-09-29', 'count': 2, 'normalized': 0.969},
#   {'date': '2021-09-28', 'count': 4, 'normalized': 0.5933},
#   {'date': '2021-09-27', 'count': 10, 'normalized': 0.6076},
#   {'date': '2021-09-26', 'count': 3, 'normalized': 0.6683},
#   {'date': '2021-09-25', 'count': 3, 'normalized': 0.5833},
#   {'date': '2021-09-24', 'count': 26, 'normalized': 0.2146},
#   {'date': '2021-09-23', 'count': 25, 'normalized': 0.2925},
#   {'date': '2021-09-22', 'count': 7, 'normalized': 0.7163},
#   {'date': '2021-09-21', 'count': 6, 'normalized': 0.923},
#   {'date': '2021-09-20', 'count': 4, 'normalized': 0.9928},
#   {'date': '2021-09-19', 'count': 4, 'normalized': 0.1418},
#   {'date': '2021-09-17', 'count': 6, 'normalized': 0.3137},
#   {'date': '2021-09-16', 'count': 3, 'normalized': 0.6823},
#   {'date': '2021-09-15', 'count': 2, 'normalized': 0.993},
#   {'date': '2021-09-13', 'count': 2, 'normalized': 0.999},
#   {'date': '2021-09-11', 'count': 2, 'normalized': 0.306},
#   {'date': '2021-09-10', 'count': 2, 'normalized': 0.835},
#   {'date': '2021-09-09', 'count': 3, 'normalized': 0.8123},
#   {'date': '2021-09-08', 'count': 2, 'normalized': 0.5625},
#   {'date': '2021-09-07', 'count': 2, 'normalized': 0.9955},
#   {'date': '2021-09-06', 'count': 1, 'normalized': 0.993},
#   {'date': '2021-09-03', 'count': 1, 'normalized': 0.35},
#   {'date': '2021-09-02', 'count': 4, 'normalized': 0.8893},
#   {'date': '2021-09-01', 'count': 3, 'normalized': 0.213},
#   {'date': '2021-08-31', 'count': 1, 'normalized': 0.796},
#   {'date': '2021-08-30', 'count': 3, 'normalized': 0.9933},
#   {'date': '2021-08-29', 'count': 1, 'normalized': 0.599},
#   {'date': '2021-08-27', 'count': 1, 'normalized': 0},
#   {'date': '2021-08-26', 'count': 1, 'normalized': 0.998},
#   {'date': '2021-08-25', 'count': 2, 'normalized': 0.9995},
#   {'date': '2021-08-24', 'count': 1, 'normalized': 0.637},
#   {'date': '2021-08-23', 'count': 2, 'normalized': 0.4995},
#   {'date': '2021-08-22', 'count': 1, 'normalized': -0.273},
#   {'date': '2021-08-21', 'count': 2, 'normalized': 0.8925},
#   {'date': '2021-08-20', 'count': 1, 'normalized': 0.891},
#   {'date': '2021-08-19', 'count': 2, 'normalized': 0.8775},
#   {'date': '2021-08-17', 'count': 4, 'normalized': 0.7455},
#   {'date': '2021-08-14', 'count': 1, 'normalized': 0},
#   {'date': '2021-08-13', 'count': 1, 'normalized': 0.7},
#   {'date': '2021-08-11', 'count': 2, 'normalized': 0.9955},
#   {'date': '2021-08-10', 'count': 2, 'normalized': 0.41},
#   {'date': '2021-08-09', 'count': 5, 'normalized': 0.9988},
#   {'date': '2021-08-06', 'count': 1, 'normalized': 1},
#   {'date': '2021-08-05', 'count': 5, 'normalized': 0.552},
#   {'date': '2021-08-04', 'count': 4, 'normalized': 0.1638},
#   {'date': '2021-08-03', 'count': 1, 'normalized': 0.751},
#   {'date': '2021-08-02', 'count': 1, 'normalized': 0.459},
#   {'date': '2021-07-31', 'count': 2, 'normalized': 0.3195},
#   {'date': '2021-07-30', 'count': 2, 'normalized': 0.9955},
#   {'date': '2021-07-29', 'count': 3, 'normalized': 0.5453},
#   {'date': '2021-07-28', 'count': 1, 'normalized': 0.985},
#   {'date': '2021-07-27', 'count': 1, 'normalized': 0.999},
#   {'date': '2021-07-26', 'count': 1, 'normalized': 0.791},
#   {'date': '2021-07-23', 'count': 2, 'normalized': 0.9995},
#   {'date': '2021-07-22', 'count': 2, 'normalized': 0.3735},
#   {'date': '2021-07-21', 'count': 3, 'normalized': 0.9817},
#   {'date': '2021-07-20', 'count': 6, 'normalized': 0.9102},
#   {'date': '2021-07-19', 'count': 5, 'normalized': 0.9016},
#   {'date': '2021-07-16', 'count': 1, 'normalized': 0.026},
#   {'date': '2021-07-14', 'count': 1, 'normalized': 0.949},
#   {'date': '2021-07-13', 'count': 3, 'normalized': 0.0293},
#   {'date': '2021-07-12', 'count': 5, 'normalized': 0.9324},
#   {'date': '2021-07-11', 'count': 1, 'normalized': 0.052},
#   {'date': '2021-07-10', 'count': 2, 'normalized': 0.3665},
#   {'date': '2021-07-09', 'count': 6, 'normalized': 0.8233},
#   {'date': '2021-07-08', 'count': 3, 'normalized': 0.0593},
#   {'date': '2021-07-07', 'count': 2, 'normalized': 0.9995},
#   {'date': '2021-07-06', 'count': 4, 'normalized': 0.7548},
#   {'date': '2021-07-04', 'count': 1, 'normalized': 0.791},
#   {'date': '2021-07-03', 'count': 1, 'normalized': 0.796},
#   {'date': '2021-07-01', 'count': 2, 'normalized': 0.999},
#   {'date': '2021-06-30', 'count': 4, 'normalized': 0.206},
#   {'date': '2021-06-29', 'count': 2, 'normalized': 0.999},
#   {'date': '2021-06-28', 'count': 4, 'normalized': 0.778},
#   {'date': '2021-06-27', 'count': 2, 'normalized': 0.44},
#   {'date': '2021-06-26', 'count': 4, 'normalized': 0.8245},
#   {'date': '2021-06-25', 'count': 4, 'normalized': 0.461},
#   {'date': '2021-06-24', 'count': 8, 'normalized': 0.7965},
#   {'date': '2021-06-23', 'count': 4, 'normalized': -0.1},
#   {'date': '2021-06-22', 'count': 6, 'normalized': 0.3813},
#   {'date': '2021-06-21', 'count': 4, 'normalized': 0.995},
#   {'date': '2021-06-20', 'count': 2, 'normalized': 0.026},
#   {'date': '2021-06-18', 'count': 2, 'normalized': 0.998},
#   {'date': '2021-06-17', 'count': 2, 'normalized': 0.999},
#   {'date': '2021-06-16', 'count': 5, 'normalized': 0.998},
#   {'date': '2021-06-15', 'count': 5, 'normalized': 0.8656},
#   {'date': '2021-06-14', 'count': 7, 'normalized': 0.9229},
#   {'date': '2021-06-11', 'count': 1, 'normalized': 0.995},
#   {'date': '2021-06-10', 'count': 2, 'normalized': 0.979},
#   {'date': '2021-06-09', 'count': 4, 'normalized': 0.5},
#   {'date': '2021-06-08', 'count': 7, 'normalized': 0.664},
#   {'date': '2021-06-07', 'count': 2, 'normalized': 0.9965},
#   {'date': '2021-06-06', 'count': 2, 'normalized': 0.5805},
#   {'date': '2021-06-05', 'count': 2, 'normalized': 0.491},
#   {'date': '2021-06-04', 'count': 2, 'normalized': 0.694},
#   {'date': '2021-06-03', 'count': 5, 'normalized': 0.3052},
#   {'date': '2021-06-02', 'count': 3, 'normalized': 0.4023},
#   {'date': '2021-06-01', 'count': 3, 'normalized': 0.989},
#   {'date': '2021-05-31', 'count': 4, 'normalized': 0.8388},
#   {'date': '2021-05-30', 'count': 3, 'normalized': 0.0987},
#   {'date': '2021-05-28', 'count': 12, 'normalized': 0.4815},
#   {'date': '2021-05-27', 'count': 17, 'normalized': 0.733},
#   {'date': '2021-05-26', 'count': 3, 'normalized': 0.44},
#   {'date': '2021-05-25', 'count': 1, 'normalized': -0.111},
#   {'date': '2021-05-24', 'count': 7, 'normalized': 0.6991},
#   {'date': '2021-05-23', 'count': 5, 'normalized': 0.7254},
#   {'date': '2021-05-22', 'count': 1, 'normalized': 0.999},
#   {'date': '2021-05-21', 'count': 1, 'normalized': 0.984},
#   {'date': '2021-05-20', 'count': 3, 'normalized': -0.362},
#   {'date': '2021-05-19', 'count': 3, 'normalized': 0.9927},
#   {'date': '2021-05-18', 'count': 3, 'normalized': 0.6017},
#   {'date': '2021-05-17', 'count': 6, 'normalized': 0.7463},
#   {'date': '2021-05-15', 'count': 4, 'normalized': 0.5473},
#   {'date': '2021-05-14', 'count': 1, 'normalized': 0.997},
#   {'date': '2021-05-13', 'count': 2, 'normalized': 0.561},
#   {'date': '2021-05-12', 'count': 5, 'normalized': 0.7046},
#   {'date': '2021-05-11', 'count': 2, 'normalized': 0.3925},
#   {'date': '2021-05-10', 'count': 1, 'normalized': 0.09},
#   {'date': '2021-05-09', 'count': 1, 'normalized': -0.572},
#   {'date': '2021-05-08', 'count': 1, 'normalized': 0.751},
#   {'date': '2021-05-07', 'count': 4, 'normalized': 0.6988},
#   {'date': '2021-05-06', 'count': 3, 'normalized': 0.769},
#   {'date': '2021-05-05', 'count': 5, 'normalized': 0.376},
#   {'date': '2021-05-04', 'count': 3, 'normalized': 0.997},
#   {'date': '2021-05-03', 'count': 8, 'normalized': 0.8874},
#   {'date': '2021-04-30', 'count': 1, 'normalized': 0.998},
#   {'date': '2021-04-29', 'count': 1, 'normalized': 0.999},
#   {'date': '2021-04-28', 'count': 2, 'normalized': 0.5095},
#   {'date': '2021-04-27', 'count': 1, 'normalized': 0.494},
#   {'date': '2021-04-26', 'count': 1, 'normalized': 0.991},
#   {'date': '2021-04-24', 'count': 2, 'normalized': 0.3685},
#   {'date': '2021-04-23', 'count': 3, 'normalized': 0.9993},
#   {'date': '2021-04-22', 'count': 2, 'normalized': 0.997},
#   {'date': '2021-04-21', 'count': 3, 'normalized': 0.574},
#   {'date': '2021-04-20', 'count': 1, 'normalized': 0.992},
#   {'date': '2021-04-19', 'count': 1, 'normalized': 0.923},
#   {'date': '2021-04-17', 'count': 1, 'normalized': 0.999},
#   {'date': '2021-04-16', 'count': 1, 'normalized': 0.318},
#   {'date': '2021-04-15', 'count': 7, 'normalized': 0.835},
#   {'date': '2021-04-14', 'count': 7, 'normalized': 0.3467},
#   {'date': '2021-04-13', 'count': 3, 'normalized': 0.1553},
#   {'date': '2021-04-12', 'count': 2, 'normalized': 0.1705},
#   {'date': '2021-04-11', 'count': 1, 'normalized': 0.382},
#   {'date': '2021-04-09', 'count': 5, 'normalized': 0.9316},
#   {'date': '2021-04-08', 'count': 7, 'normalized': 0.5347},
#   {'date': '2021-04-07', 'count': 5, 'normalized': -0.0322},
#   {'date': '2021-04-06', 'count': 4, 'normalized': 0.7285},
#   {'date': '2021-04-05', 'count': 2, 'normalized': 0.728},
#   {'date': '2021-04-04', 'count': 1, 'normalized': 0.361},
#   {'date': '2021-04-02', 'count': 1, 'normalized': -0.318},
#   {'date': '2021-03-31', 'count': 4, 'normalized': 0.692},
#   {'date': '2021-03-30', 'count': 1, 'normalized': 0.997},
#   {'date': '2021-03-29', 'count': 1, 'normalized': 0.999},
#   {'date': '2021-03-28', 'count': 1, 'normalized': 0.351},
#   {'date': '2021-03-27', 'count': 1, 'normalized': 0.586},
#   {'date': '2021-03-26', 'count': 2, 'normalized': 0.907},
#   {'date': '2021-03-25', 'count': 3, 'normalized': 0.7323},
#   {'date': '2021-03-24', 'count': 5, 'normalized': 0.194},
#   {'date': '2021-03-23', 'count': 1, 'normalized': 0.999},
#   {'date': '2021-03-22', 'count': 2, 'normalized': 0.954},
#   {'date': '2021-03-21', 'count': 4, 'normalized': 0.9965},
#   {'date': '2021-03-19', 'count': 2, 'normalized': 0.9785},
#   {'date': '2021-03-18', 'count': 1, 'normalized': 0.999},
#   {'date': '2021-03-17', 'count': 4, 'normalized': 0.7045},
#   {'date': '2021-03-16', 'count': 6, 'normalized': 0.7067},
#   {'date': '2021-03-15', 'count': 5, 'normalized': 0.9928},
#   {'date': '2021-03-14', 'count': 2, 'normalized': 0.877},
#   {'date': '2021-03-13', 'count': 1, 'normalized': 0.872},
#   {'date': '2021-03-12', 'count': 4, 'normalized': 0.8853},
#   {'date': '2021-03-11', 'count': 6, 'normalized': 0.584},
#   {'date': '2021-03-08', 'count': 4, 'normalized': 0.7605},
#   {'date': '2021-03-06', 'count': 1, 'normalized': 0.996},
#   {'date': '2021-03-05', 'count': 10, 'normalized': 0.9255},
#   {'date': '2021-03-04', 'count': 4, 'normalized': 0.7335},
#   {'date': '2021-03-03', 'count': 2, 'normalized': 0.943},
#   {'date': '2021-03-02', 'count': 4, 'normalized': 0.9955},
#   {'date': '2021-03-01', 'count': 7, 'normalized': 0.8513},
#   {'date': '2021-02-28', 'count': 2, 'normalized': 0.991},
#   {'date': '2021-02-27', 'count': 2, 'normalized': 0.4615},
#   {'date': '2021-02-26', 'count': 3, 'normalized': -0.8383},
#   {'date': '2021-02-25', 'count': 2, 'normalized': 0.889},
#   {'date': '2021-02-24', 'count': 4, 'normalized': 0.4225},
#   {'date': '2021-02-18', 'count': 2, 'normalized': 0.997},
#   {'date': '2021-02-12', 'count': 2, 'normalized': 0.994},
#   {'date': '2021-02-11', 'count': 2, 'normalized': 0.927},
#   {'date': '2021-02-08', 'count': 2, 'normalized': 0.998},
#   {'date': '2021-02-05', 'count': 2, 'normalized': 1},
#   {'date': '2021-02-03', 'count': 1, 'normalized': -0.511},
#   {'date': '2021-01-21', 'count': 1, 'normalized': -0.613},
#   {'date': '2021-01-20', 'count': 2, 'normalized': 0.997},
#   {'date': '2021-01-19', 'count': 1, 'normalized': 0.999},
#   {'date': '2021-01-08', 'count': 1, 'normalized': 0.94},
#   {'date': '2021-01-06', 'count': 1, 'normalized': -0.511},
#   {'date': '2020-12-28', 'count': 1, 'normalized': 0.999},
#   {'date': '2020-12-12', 'count': 2, 'normalized': 0.928},
#   {'date': '2020-12-10', 'count': 1, 'normalized': 0.985},
#   {'date': '2020-12-02', 'count': 1, 'normalized': -0.393},
#   {'date': '2020-11-27', 'count': 1, 'normalized': 0.999},
#   {'date': '2020-11-19', 'count': 2, 'normalized': 0.986},
#   {'date': '2020-11-16', 'count': 1, 'normalized': 0.822},
#   {'date': '2020-11-09', 'count': 1, 'normalized': 0.994},
#   {'date': '2020-11-05', 'count': 1, 'normalized': 1},
#   {'date': '2020-11-04', 'count': 1, 'normalized': -0.511},
#   {'date': '2020-10-28', 'count': 1, 'normalized': 0.999},
#   {'date': '2020-10-19', 'count': 2, 'normalized': 0.988},
#   {'date': '2020-10-16', 'count': 1, 'normalized': 0.995},
#   {'date': '2020-10-14', 'count': 1, 'normalized': -0.613},
#   {'date': '2020-10-12', 'count': 2, 'normalized': 0.952},
#   {'date': '2020-10-07', 'count': 1, 'normalized': 0.518},
#   {'date': '2020-10-01', 'count': 1, 'normalized': 0.993},
#   {'date': '2020-09-30', 'count': 1, 'normalized': 0.984},
#   {'date': '2020-09-25', 'count': 4, 'normalized': 0.613},
#   {'date': '2020-09-24', 'count': 1, 'normalized': 0.992},
#   {'date': '2020-09-03', 'count': 1, 'normalized': -0.302},
#   {'date': '2020-09-02', 'count': 1, 'normalized': -0.613},
#   {'date': '2020-08-05', 'count': 1, 'normalized': -0.511},
#   {'date': '2020-07-15', 'count': 1, 'normalized': -0.613},
#   {'date': '2020-07-09', 'count': 1, 'normalized': 0.995},
#   {'date': '2020-07-08', 'count': 1, 'normalized': -0.511},
#   {'date': '2020-07-01', 'count': 1, 'normalized': 0.997},
#   {'date': '2020-06-04', 'count': 1, 'normalized': 0.997},
#   {'date': '2020-06-03', 'count': 1, 'normalized': -0.511},
#   {'date': '2020-05-29', 'count': 1, 'normalized': 0.999},
#   {'date': '2020-05-28', 'count': 1, 'normalized': 0.984},
#   {'date': '2020-05-27', 'count': 1, 'normalized': 0.997},
#   {'date': '2020-05-06', 'count': 1, 'normalized': -0.52},
#   {'date': '2020-05-05', 'count': 1, 'normalized': 0.998},
#   {'date': '2020-04-22', 'count': 1, 'normalized': 0.998},
#   {'date': '2020-04-16', 'count': 1, 'normalized': -0.297},
#   {'date': '2020-04-15', 'count': 1, 'normalized': -0.643},
#   {'date': '2020-04-08', 'count': 1, 'normalized': -0.46},
#   {'date': '2020-03-17', 'count': 1, 'normalized': 0.978},
#   {'date': '2020-03-05', 'count': 1, 'normalized': 0.995},
#   {'date': '2020-02-05', 'count': 1, 'normalized': 0.927},
#   {'date': '2020-01-23', 'count': 1, 'normalized': 0.948},
#   {'date': '2020-01-08', 'count': 1, 'normalized': 0.967},
#   {'date': '2019-12-12', 'count': 1, 'normalized': 0.996},
#   {'date': '2019-12-04', 'count': 1, 'normalized': 0.958},
#   {'date': '2019-11-06', 'count': 1, 'normalized': 0.953},
#   {'date': '2019-10-18', 'count': 1, 'normalized': 0.948},
#   {'date': '2019-10-09', 'count': 2, 'normalized': 0.3445},
#   {'date': '2019-10-03', 'count': 1, 'normalized': 0.992},
#   {'date': '2019-10-01', 'count': 1, 'normalized': 0.997},
#   {'date': '2019-09-05', 'count': 1, 'normalized': 0.888},
#   {'date': '2019-08-13', 'count': 1, 'normalized': 0.846},
#   {'date': '2019-08-07', 'count': 1, 'normalized': 0.87},
#   {'date': '2019-07-10', 'count': 1, 'normalized': 0.87},
#   {'date': '2019-06-05', 'count': 1, 'normalized': 0.87},
#   {'date': '2019-05-30', 'count': 1, 'normalized': 0.991},
#   {'date': '2019-05-08', 'count': 1, 'normalized': 0.87},
#   {'date': '2019-05-03', 'count': 1, 'normalized': 0.994},
#   {'date': '2019-04-26', 'count': 1, 'normalized': 0.886},
#   {'date': '2019-04-10', 'count': 1, 'normalized': 0.901},
#   {'date': '2019-03-27', 'count': 1, 'normalized': 0.998},
#   {'date': '2019-03-12', 'count': 1, 'normalized': 1},
#   {'date': '2019-03-07', 'count': 1, 'normalized': 0.991},
#   {'date': '2019-02-15', 'count': 1, 'normalized': 0.995},
#   {'date': '2019-02-06', 'count': 1, 'normalized': 0.902},
#   {'date': '2019-02-04', 'count': 1, 'normalized': 0.856},
#   {'date': '2019-01-24', 'count': 1, 'normalized': 0.846},
#   {'date': '2019-01-09', 'count': 1, 'normalized': 0.87},
#   {'date': '2019-01-07', 'count': 1, 'normalized': -0.904},
#   {'date': '2019-01-05', 'count': 2, 'normalized': 0.903},
#   {'date': '2019-01-03', 'count': 2, 'normalized': -0.294},
#   {'date': '2019-01-01', 'count': 1, 'normalized': -0.904},
#   {'date': '2018-12-30', 'count': 1, 'normalized': 0.903},
#   {'date': '2018-12-29', 'count': 1, 'normalized': -0.969},
#   {'date': '2018-12-27', 'count': 2, 'normalized': 0.7465},
#   {'date': '2018-12-26', 'count': 1, 'normalized': -0.294},
#   {'date': '2018-12-24', 'count': 1, 'normalized': -0.904},
#   {'date': '2018-12-19', 'count': 2, 'normalized': -0.599},
#   {'date': '2018-12-14', 'count': 1, 'normalized': -0.294},
#   {'date': '2018-12-13', 'count': 3, 'normalized': 0.24},
#   {'date': '2018-12-11', 'count': 2, 'normalized': -0.0005},
#   {'date': '2018-12-07', 'count': 1, 'normalized': -0.294},
#   {'date': '2018-12-06', 'count': 1, 'normalized': 0.888},
#   {'date': '2018-12-04', 'count': 1, 'normalized': -0.904},
#   {'date': '2018-12-02', 'count': 1, 'normalized': -0.981},
#   {'date': '2018-11-28', 'count': 1, 'normalized': 0.995},
#   {'date': '2018-11-27', 'count': 2, 'normalized': -0.599},
#   {'date': '2018-11-20', 'count': 1, 'normalized': 0.981},
#   {'date': '2018-11-19', 'count': 1, 'normalized': -0.904},
#   {'date': '2018-11-14', 'count': 1, 'normalized': -0.904},
#   {'date': '2018-11-09', 'count': 1, 'normalized': -0.904},
#   {'date': '2018-11-07', 'count': 2, 'normalized': 0.8465},
#   {'date': '2018-10-24', 'count': 1, 'normalized': 0.846},
#   {'date': '2018-10-19', 'count': 1, 'normalized': 0.994},
#   {'date': '2018-10-10', 'count': 1, 'normalized': 0.881},
#   {'date': '2018-10-04', 'count': 1, 'normalized': 0.994},
#   {'date': '2018-10-02', 'count': 1, 'normalized': 0.997},
#   {'date': '2018-09-06', 'count': 1, 'normalized': 0.896},
#   {'date': '2018-08-17', 'count': 1, 'normalized': 0.857},
#   {'date': '2018-08-08', 'count': 1, 'normalized': 0.879},
#   {'date': '2018-07-26', 'count': 1, 'normalized': 0.998},
#   {'date': '2018-07-11', 'count': 1, 'normalized': 0.879},
#   {'date': '2018-06-07', 'count': 1, 'normalized': 0.879},
#   {'date': '2018-05-31', 'count': 1, 'normalized': 0.992},
#   {'date': '2018-05-25', 'count': 1, 'normalized': 0.999},
#   {'date': '2018-05-10', 'count': 1, 'normalized': 0.907},
#   {'date': '2018-05-04', 'count': 1, 'normalized': 0.998},
#   {'date': '2018-04-24', 'count': 1, 'normalized': 0.9},
#   {'date': '2018-04-12', 'count': 1, 'normalized': 0.879},
#   {'date': '2018-04-03', 'count': 1, 'normalized': 0.997},
#   {'date': '2018-03-07', 'count': 1, 'normalized': 0.995},
#   {'date': '2018-02-20', 'count': 1, 'normalized': 0.992},
#   {'date': '2018-02-08', 'count': 1, 'normalized': 0.879},
#   {'date': '2018-02-02', 'count': 1, 'normalized': 0.997},
#   {'date': '2018-01-30', 'count': 1, 'normalized': 0.857},
#   {'date': '2018-01-04', 'count': 1, 'normalized': 0.907},
#   {'date': '2017-12-14', 'count': 1, 'normalized': 0.994},
#   {'date': '2017-12-12', 'count': 1, 'normalized': 0.993},
#   {'date': '2017-11-30', 'count': 1, 'normalized': 0.903},
#   {'date': '2017-11-28', 'count': 1, 'normalized': 0.997},
#   {'date': '2017-11-02', 'count': 2, 'normalized': 0.879},
#   {'date': '2017-10-30', 'count': 1, 'normalized': 0.857},
#   {'date': '2017-10-05', 'count': 1, 'normalized': 0.994},
#   {'date': '2017-10-04', 'count': 1, 'normalized': 0.997},
#   {'date': '2017-08-31', 'count': 1, 'normalized': 0.901},
#   {'date': '2017-08-24', 'count': 2, 'normalized': 0.998},
#   {'date': '2017-08-14', 'count': 1, 'normalized': 0.854},
#   {'date': '2017-08-10', 'count': 1, 'normalized': 0.834},
#   {'date': '2017-08-03', 'count': 1, 'normalized': 0.879},
#   {'date': '2017-08-01', 'count': 1, 'normalized': 0.799},
#   {'date': '2017-07-31', 'count': 1, 'normalized': 0.857},
#   {'date': '2017-07-06', 'count': 1, 'normalized': 0.879},
#   {'date': '2017-06-01', 'count': 1, 'normalized': 0.879},
#   {'date': '2017-05-25', 'count': 1, 'normalized': 0.996},
#   {'date': '2017-05-09', 'count': 1, 'normalized': 0.897},
#   {'date': '2017-05-04', 'count': 1, 'normalized': 0.879},
#   {'date': '2017-04-25', 'count': 1, 'normalized': 0.98},
#   {'date': '2017-04-06', 'count': 1, 'normalized': 0.907},
#   {'date': '2017-03-20', 'count': 1, 'normalized': 0.956},
#   {'date': '2017-03-02', 'count': 1, 'normalized': 0.995},
#   {'date': '2017-02-02', 'count': 1, 'normalized': 0.879},
#   {'date': '2017-01-27', 'count': 1, 'normalized': 0.857},
#   {'date': '2017-01-05', 'count': 1, 'normalized': 0.879},
#   {'date': '2016-12-07', 'count': 1, 'normalized': 0.997},
#   {'date': '2016-11-03', 'count': 1, 'normalized': 0.879},
#   {'date': '2016-10-12', 'count': 1, 'normalized': 0.857},
#   {'date': '2016-10-06', 'count': 1, 'normalized': 0.859},
#   {'date': '2016-10-05', 'count': 1, 'normalized': 0.852},
#   {'date': '2016-09-29', 'count': 2, 'normalized': 0.945},
#   {'date': '2016-09-01', 'count': 1, 'normalized': 0.896},
#   {'date': '2016-08-04', 'count': 1, 'normalized': 0.84},
#   {'date': '2016-07-25', 'count': 1, 'normalized': 0.857},
#   {'date': '2016-07-07', 'count': 1, 'normalized': 0.831},
#   {'date': '2016-06-02', 'count': 1, 'normalized': 0.875},
#   {'date': '2016-05-26', 'count': 1, 'normalized': 0.998},
#   {'date': '2016-05-05', 'count': 1, 'normalized': 0.831},
#   {'date': '2016-04-14', 'count': 1, 'normalized': 0.912},
#   {'date': '2016-04-13', 'count': 1, 'normalized': 0.882},
#   {'date': '2016-04-11', 'count': 1, 'normalized': 0.974},
#   {'date': '2016-04-07', 'count': 1, 'normalized': 0.831},
#   {'date': '2016-03-03', 'count': 1, 'normalized': 0.998},
#   {'date': '2016-02-04', 'count': 1, 'normalized': 0.79},
#   {'date': '2016-01-07', 'count': 1, 'normalized': 0.831},
#   {'date': '2015-12-09', 'count': 1, 'normalized': 0.997},
#   {'date': '2015-12-03', 'count': 1, 'normalized': 0.857},
#   {'date': '2015-11-05', 'count': 1, 'normalized': 0.831},
#   {'date': '2015-10-29', 'count': 2, 'normalized': 0.904},
#   {'date': '2015-10-14', 'count': 1, 'normalized': 0.954},
#   {'date': '2015-10-08', 'count': 1, 'normalized': 0.799},
#   {'date': '2015-09-30', 'count': 1, 'normalized': 0.998},
#   {'date': '2015-09-03', 'count': 1, 'normalized': 0.831},
#   {'date': '2015-08-06', 'count': 1, 'normalized': 0.831},
#   {'date': '2015-07-27', 'count': 1, 'normalized': 0.857},
#   {'date': '2015-07-09', 'count': 1, 'normalized': 0.831}]}

# %%
sent_df
# Out:
#            date  count  normalized
# 0    2023-06-10      7      0.4311
# 1    2023-06-08      8      0.6186
# 2    2023-06-07      1      0.8890
# 3    2023-06-06      6      0.5995
# 4    2023-06-05      1      1.0000
# ..          ...    ...         ...
# 905  2015-09-30      1      0.9980
# 906  2015-09-03      1      0.8310
# 907  2015-08-06      1      0.8310
# 908  2015-07-27      1      0.8570
# 909  2015-07-09      1      0.8310
#
# [910 rows x 3 columns]

# %%
url = 'https://eodhistoricaldata.com/api/sentiments?s={}&from=2000-01-01&to=2023-06-30&api_token=64804202d365e9.21480491'.format(stock)
response = requests.get(url)
data = response.json()
ticker = list(data.keys())[0]
sent_df = pd.DataFrame(data[ticker])

sent_df = sent_df[sent_df['date'] >= '2017-11-28']
df_new=merged_df
sent_df['date'] = pd.to_datetime(sent_df['date'])
df_new.set_index('Date_x', inplace=True)
sent_df.set_index('date', inplace=True)

df_new.index = df_new.index.tz_localize(None)
new_merged_df = df_new.merge(sent_df, how='outer', left_index=True, right_index=True)
new_merged_df.fillna(method='ffill', inplace=True)
new_merged_df.fillna(method='bfill', inplace=True)
new_merged_df.dropna(inplace=True)
new_merged_df.reset_index(inplace=True)
new_merged_df.rename(columns={"level_0":"date"},inplace=True)
new_merged_df = new_merged_df.iloc[1: , :]
dfr=new_merged_df

df1=new_merged_df
#dfr=merged_df

df1=df1.drop(['Open','High','Low','Dividends','NASDAQCOM','index','count'],axis=1)
df1['date'] = pd.to_numeric(df1['date'])

# %%
response
# Out:
# <Response [200]>

# %%
url = 'https://eodhistoricaldata.com/api/tweets-sentiments?s={}&from=2000-01-01&to=2023-06-30&api_token=6481b11d245909.63698937'.format(stock)
response = requests.get(url)
data = response.json()
ticker = list(data.keys())[0]
tweet_df = pd.DataFrame(data[ticker])
tweet_df = tweet_df.rename({'normalized': 'tweet_normalized'}, axis='columns')
tweet_df['date'] = pd.to_datetime(tweet_df['date'])
df_new2 = new_merged_df.merge(tweet_df, how='outer', left_index=True, right_index=True)
df_new2.fillna(method='ffill', inplace=True)
df_new2.fillna(method='bfill', inplace=True)
df_new2.dropna(axis = 0, inplace=True)
df_new2.rename(columns={"date_x":"date"},inplace=True)
df_new2 = df_new2.iloc[1: , :]
df_lstm=df_new2
dfr=df_new2

# %%
df_new2
# Out:
#            date        Open        High         Low       Close     Volume  \
# 1    2017-11-30  174.115640  177.323985  173.659971  175.129303  2509300.0
# 2    2017-12-12  174.115640  177.323985  173.659971  175.129303  2509300.0
# 3    2017-12-14  174.115640  177.323985  173.659971  175.129303  2509300.0
# 4    2018-01-02  174.115640  177.323985  173.659971  175.129303  2509300.0
# 5    2018-01-03  175.594316  178.644571  175.185133  177.231033  3364400.0
# ...         ...         ...         ...         ...         ...        ...
# 1548 2023-06-06  518.250000  518.630005  512.760010  516.260010  1410300.0
# 1549 2023-06-07  514.510010  519.289978  510.570007  511.230011  1784700.0
# 1550 2023-06-08  512.500000  520.289978  512.500000  520.090027  1530400.0
# 1551 2023-06-09  518.190002  522.059998  515.500000  517.280029  1287300.0
# 1552 2023-06-10  518.190002  522.059998  515.500000  517.280029  1287300.0
#
#       Dividends  Stock Splits  Job_Value  Labour_values  ...             1  \
# 1           0.0           0.0   70.31713           41.0  ...  2.043908e+14
# 2           0.0           0.0   70.31713           41.0  ...  2.043908e+14
# 3           0.0           0.0   70.31713           41.0  ...  2.043908e+14
# 4           0.0           0.0   70.31713           41.0  ...  2.043908e+14
# 5           0.0           0.0   70.31713           41.0  ...  2.043908e+14
# ...         ...           ...        ...            ...  ...           ...
# 1548        0.0           0.0   71.68311           42.0  ... -5.544624e+14
# 1549        0.0           0.0   71.68311           42.0  ... -5.544624e+14
# 1550        0.0           0.0   71.68311           42.0  ... -5.544624e+14
# 1551        0.0           0.0   71.68311           42.0  ... -5.544624e+14
# 1552        0.0           0.0   71.68311           42.0  ... -5.544624e+14
#
#                  2             3             4             5  count_x  \
# 1     6.212892e+13  3.573442e+14  1.128857e+14  3.320616e+14      1.0
# 2     6.212892e+13  3.573442e+14  1.128857e+14  3.320616e+14      1.0
# 3     6.212892e+13  3.573442e+14  1.128857e+14  3.320616e+14      1.0
# 4     6.212892e+13  3.573442e+14  1.128857e+14  3.320616e+14      1.0
# 5     6.212892e+13  3.573442e+14  1.128857e+14  3.320616e+14      1.0
# ...            ...           ...           ...           ...      ...
# 1548 -1.685406e+14 -9.693878e+14 -3.062315e+14 -9.008022e+14      6.0
# 1549 -1.685406e+14 -9.693878e+14 -3.062315e+14 -9.008022e+14      1.0
# 1550 -1.685406e+14 -9.693878e+14 -3.062315e+14 -9.008022e+14      8.0
# 1551 -1.685406e+14 -9.693878e+14 -3.062315e+14 -9.008022e+14      8.0
# 1552 -1.685406e+14 -9.693878e+14 -3.062315e+14 -9.008022e+14      7.0
#
#       normalized     date_y  count_y  tweet_normalized
# 1         0.9030 2023-03-13     79.0            0.1781
# 2         0.9930 2023-03-12     91.0            0.1799
# 3         0.9940 2023-03-11    117.0            0.2210
# 4         0.9940 2023-03-10     94.0            0.2442
# 5         0.9940 2023-03-09     99.0            0.2970
# ...          ...        ...      ...               ...
# 1548      0.5995 2021-12-21     25.0            0.1755
# 1549      0.8890 2021-12-21     25.0            0.1755
# 1550      0.6186 2021-12-21     25.0            0.1755
# 1551      0.6186 2021-12-21     25.0            0.1755
# 1552      0.4311 2021-12-21     25.0            0.1755
#
# [1552 rows x 27 columns]

# %%
df_lstm.columns
# Out:
# Index([               'date',                'Open',                'High',
#                        'Low',               'Close',              'Volume',
#                  'Dividends',        'Stock Splits',           'Job_Value',
#              'Labour_values', 'Manufacturing_Value',           'CPI_Value',
#            'inflation_Value',       'Housing_value',           'NASDAQCOM',
#                      'index',                   '0',                   '1',
#                          '2',                   '3',                   '4',
#                            5,             'count_x',          'normalized',
#                     'date_y',             'count_y',    'tweet_normalized'],
#       dtype='object')

# %%
df_lstm=df_lstm.drop(['Open','High','Low','Dividends','NASDAQCOM','index','count_x','count_y','date_y'],axis=1)
df_lstm['date'] = pd.to_numeric(df_lstm['date'])
df_lstm.dropna(axis = 0, inplace=True)

# %%
def train_lstm(df_lstm):
    features=['tweet_normalized','Close','Volume','normalized','Job_Value','Labour_values',
              'Manufacturing_Value','CPI_Value','inflation_Value','Housing_value','0','1','2','3','4']
    scaler = MinMaxScaler()
    data_scaled = scaler.fit_transform(df_lstm[features])
    n_steps = 100 # number of time steps to consider for each input
    n_features = len(features)
    model = Sequential()
    model.add(LSTM(units=50, activation='relu', input_shape=(n_steps, n_features)))
    model.add(Dense(15, activation='linear'))
    model.compile(optimizer='adam', loss='mean_squared_error')
    X_train = []
    y_train = []
    for i in range(n_steps, len(df_lstm)-1):
        X_train.append(data_scaled[i-n_steps:i])
        y_train.append(data_scaled[i+1, :]) # predict all 15 columns for next day
    X_train, y_train = np.array(X_train), np.array(y_train)
    print('X_train shape:', X_train.shape)
    print('y_train shape:', y_train.shape)
    model.fit(X_train, y_train, epochs=50, batch_size=32)
    return model, scaler, n_steps, n_features, X_train, y_train

# %%
df
# Out:
#                           Date        Open        High         Low  \
# 0    2005-01-03 00:00:00-05:00   33.691786   34.215601   33.349559
# 1    2005-01-04 00:00:00-05:00   33.656853   33.761617   32.853672
# 2    2005-01-05 00:00:00-05:00   32.951471   33.426397   32.769880
# 3    2005-01-06 00:00:00-05:00   34.124805   34.145757   33.356542
# 4    2005-01-07 00:00:00-05:00   33.258784   33.496247   33.084179
# ...                        ...         ...         ...         ...
# 4636 2023-06-05 00:00:00-04:00  512.590027  518.919983  512.020020
# 4637 2023-06-06 00:00:00-04:00  518.250000  518.630005  512.760010
# 4638 2023-06-07 00:00:00-04:00  514.510010  519.289978  510.570007
# 4639 2023-06-08 00:00:00-04:00  512.500000  520.289978  512.500000
# 4640 2023-06-09 00:00:00-04:00  518.190002  522.059998  515.500000
#
#            Close   Volume  Dividends  Stock Splits
# 0      33.454323  2219300        0.0           0.0
# 1      32.853672  3280200        0.0           0.0
# 2      32.979408  2672900        0.0           0.0
# 3      33.454323  3771700        0.0           0.0
# 4      33.167992  2448200        0.0           0.0
# ...          ...      ...        ...           ...
# 4636  518.250000  2023500        0.0           0.0
# 4637  516.260010  1410300        0.0           0.0
# 4638  511.230011  1784700        0.0           0.0
# 4639  520.090027  1530400        0.0           0.0
# 4640  517.280029  1287300        0.0           0.0
#
# [4641 rows x 8 columns]

# %%
model, scaler, n_steps, n_features, X_train, y_train = train_lstm(df_lstm)
# Out:
# X_train shape: (1451, 100, 15)
# y_train shape: (1451, 15)
# Epoch 1/50
# 46/46 [==============================] - 5s 50ms/step - loss: 0.1033
# Epoch 2/50
# 46/46 [==============================] - 2s 44ms/step - loss: 0.0135
# Epoch 3/50
# 46/46 [==============================] - 2s 46ms/step - loss: 0.0105
# Epoch 4/50
# 46/46 [==============================] - 2s 46ms/step - loss: 0.0086
# Epoch 5/50
# 46/46 [==============================] - 2s 45ms/step - loss: 0.0073
# Epoch 6/50
# 46/46 [==============================] - 2s 47ms/step - loss: 0.0067
# Epoch 7/50
# 46/46 [==============================] - 2s 43ms/step - loss: 0.0063
# Epoch 8/50
# 46/46 [==============================] - 2s 44ms/step - loss: 0.0060
# Epoch 9/50
# 46/46 [==============================] - 2s 51ms/step - loss: 0.0058
# Epoch 10/50
# 46/46 [==============================] - 2s 49ms/step - loss: 0.0056
# Epoch 11/50
# 46/46 [==============================] - 2s 46ms/step - loss: 0.0055
# Epoch 12/50
# 46/46 [==============================] - 2s 44ms/step - loss: 0.0053
# Epoch 13/50
# 46/46 [==============================] - 2s 46ms/step - loss: 0.0052
# Epoch 14/50
# 46/46 [==============================] - 2s 44ms/step - loss: 0.0051
# Epoch 15/50
# 46/46 [==============================] - 2s 44ms/step - loss: 0.0051
# Epoch 16/50
# 46/46 [==============================] - 2s 44ms/step - loss: 0.0050
# Epoch 17/50
# 46/46 [==============================] - 2s 44ms/step - loss: 0.0050
# Epoch 18/50
# 46/46 [==============================] - 2s 43ms/step - loss: 0.0049
# Epoch 19/50
# 46/46 [==============================] - 2s 45ms/step - loss: 0.0048
# Epoch 20/50
# 46/46 [==============================] - 2s 48ms/step - loss: 0.0047
# Epoch 21/50
# 46/46 [==============================] - 2s 43ms/step - loss: 0.0046
# Epoch 22/50
# 46/46 [==============================] - 2s 40ms/step - loss: 0.0047
# Epoch 23/50
# 46/46 [==============================] - 2s 40ms/step - loss: 0.0047
# Epoch 24/50
# 46/46 [==============================] - 2s 41ms/step - loss: 0.0047
# Epoch 25/50
# 46/46 [==============================] - 2s 41ms/step - loss: 0.0047
# Epoch 26/50
# 46/46 [==============================] - 2s 40ms/step - loss: 0.0046
# Epoch 27/50
# 46/46 [==============================] - 2s 40ms/step - loss: 0.0046
# Epoch 28/50
# 46/46 [==============================] - 2s 40ms/step - loss: 0.0046
# Epoch 29/50
# 46/46 [==============================] - 2s 40ms/step - loss: 0.0046
# Epoch 30/50
# 46/46 [==============================] - 2s 41ms/step - loss: 0.0045
# Epoch 31/50
# 46/46 [==============================] - 2s 40ms/step - loss: 0.0045
# Epoch 32/50
# 46/46 [==============================] - 2s 40ms/step - loss: 0.0045
# Epoch 33/50
# 46/46 [==============================] - 2s 40ms/step - loss: 0.0045
# Epoch 34/50
# 46/46 [==============================] - 2s 40ms/step - loss: 0.0044
# Epoch 35/50
# 46/46 [==============================] - 2s 42ms/step - loss: 0.0045
# Epoch 36/50
# 46/46 [==============================] - 2s 41ms/step - loss: 0.0045
# Epoch 37/50
# 46/46 [==============================] - 2s 41ms/step - loss: 0.0044
# Epoch 38/50
# 46/46 [==============================] - 2s 40ms/step - loss: 0.0044
# Epoch 39/50
# 46/46 [==============================] - 2s 40ms/step - loss: 0.0044
# Epoch 40/50
# 46/46 [==============================] - 2s 42ms/step - loss: 0.0044
# Epoch 41/50
# 46/46 [==============================] - 2s 40ms/step - loss: 0.0043
# Epoch 42/50
# 46/46 [==============================] - 2s 40ms/step - loss: 0.0044
# Epoch 43/50
# 46/46 [==============================] - 2s 40ms/step - loss: 0.0044
# Epoch 44/50
# 46/46 [==============================] - 2s 40ms/step - loss: 0.0044
# Epoch 45/50
# 46/46 [==============================] - 2s 40ms/step - loss: 0.0044
# Epoch 46/50
# 46/46 [==============================] - 2s 42ms/step - loss: 0.0043
# Epoch 47/50
# 46/46 [==============================] - 2s 40ms/step - loss: 0.0043
# Epoch 48/50
# 46/46 [==============================] - 2s 40ms/step - loss: 0.0043
# Epoch 49/50
# 46/46 [==============================] - 2s 41ms/step - loss: 0.0043
# Epoch 50/50
# 46/46 [==============================] - 2s 40ms/step - loss: 0.0043

# %%
def lstm_predict(model, scaler, n_steps, n_features, df_lstm):
    features = ['tweet_normalized', 'Close', 'Volume', 'normalized', 'Job_Value', 'Labour_values', 'Manufacturing_Value', 'CPI_Value', 'inflation_Value', 'Housing_value', '0','1','2','3','4']
    data_scaled = scaler.transform(df_lstm[features])
    X_test = []
    X_test.append(data_scaled[-n_steps:])
    X_test = np.array(X_test)
    y_pred_scaled = model.predict(X_test)
    y_pred = scaler.inverse_transform(y_pred_scaled)

    for i in range(30):
        X_test = np.append(X_test[:,1:,:], y_pred_scaled.reshape(1,1,n_features), axis=1)
        y_pred_scaled = model.predict(X_test[:, -n_steps:, :])
        y_pred = np.append(y_pred, scaler.inverse_transform(y_pred_scaled), axis=0)
        #print(y_pred)

    return y_pred[:,1]  # return Close column values

# %%
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Dividends',
#        'Stock Splits'],
#       dtype='object')

# %%
dfr
# Out:
#            date        Open        High         Low       Close     Volume  \
# 1    2017-11-30  174.115640  177.323985  173.659971  175.129303  2509300.0
# 2    2017-12-12  174.115640  177.323985  173.659971  175.129303  2509300.0
# 3    2017-12-14  174.115640  177.323985  173.659971  175.129303  2509300.0
# 4    2018-01-02  174.115640  177.323985  173.659971  175.129303  2509300.0
# 5    2018-01-03  175.594316  178.644571  175.185133  177.231033  3364400.0
# ...         ...         ...         ...         ...         ...        ...
# 1548 2023-06-06  518.250000  518.630005  512.760010  516.260010  1410300.0
# 1549 2023-06-07  514.510010  519.289978  510.570007  511.230011  1784700.0
# 1550 2023-06-08  512.500000  520.289978  512.500000  520.090027  1530400.0
# 1551 2023-06-09  518.190002  522.059998  515.500000  517.280029  1287300.0
# 1552 2023-06-10  518.190002  522.059998  515.500000  517.280029  1287300.0
#
#       Dividends  Stock Splits  Job_Value  Labour_values  ...             1  \
# 1           0.0           0.0   70.31713           41.0  ...  2.043908e+14
# 2           0.0           0.0   70.31713           41.0  ...  2.043908e+14
# 3           0.0           0.0   70.31713           41.0  ...  2.043908e+14
# 4           0.0           0.0   70.31713           41.0  ...  2.043908e+14
# 5           0.0           0.0   70.31713           41.0  ...  2.043908e+14
# ...         ...           ...        ...            ...  ...           ...
# 1548        0.0           0.0   71.68311           42.0  ... -5.544624e+14
# 1549        0.0           0.0   71.68311           42.0  ... -5.544624e+14
# 1550        0.0           0.0   71.68311           42.0  ... -5.544624e+14
# 1551        0.0           0.0   71.68311           42.0  ... -5.544624e+14
# 1552        0.0           0.0   71.68311           42.0  ... -5.544624e+14
#
#                  2             3             4             5  count_x  \
# 1     6.212892e+13  3.573442e+14  1.128857e+14  3.320616e+14      1.0
# 2     6.212892e+13  3.573442e+14  1.128857e+14  3.320616e+14      1.0
# 3     6.212892e+13  3.573442e+14  1.128857e+14  3.320616e+14      1.0
# 4     6.212892e+13  3.573442e+14  1.128857e+14  3.320616e+14      1.0
# 5     6.212892e+13  3.573442e+14  1.128857e+14  3.320616e+14      1.0
# ...            ...           ...           ...           ...      ...
# 1548 -1.685406e+14 -9.693878e+14 -3.062315e+14 -9.008022e+14      6.0
# 1549 -1.685406e+14 -9.693878e+14 -3.062315e+14 -9.008022e+14      1.0
# 1550 -1.685406e+14 -9.693878e+14 -3.062315e+14 -9.008022e+14      8.0
# 1551 -1.685406e+14 -9.693878e+14 -3.062315e+14 -9.008022e+14      8.0
# 1552 -1.685406e+14 -9.693878e+14 -3.062315e+14 -9.008022e+14      7.0
#
#       normalized     date_y  count_y  tweet_normalized
# 1         0.9030 2023-03-13     79.0            0.1781
# 2         0.9930 2023-03-12     91.0            0.1799
# 3         0.9940 2023-03-11    117.0            0.2210
# 4         0.9940 2023-03-10     94.0            0.2442
# 5         0.9940 2023-03-09     99.0            0.2970
# ...          ...        ...      ...               ...
# 1548      0.5995 2021-12-21     25.0            0.1755
# 1549      0.8890 2021-12-21     25.0            0.1755
# 1550      0.6186 2021-12-21     25.0            0.1755
# 1551      0.6186 2021-12-21     25.0            0.1755
# 1552      0.4311 2021-12-21     25.0            0.1755
#
# [1552 rows x 27 columns]

# %%
df=dfr
df=df.drop(['Open','High','Low','Dividends','NASDAQCOM','index','index','count_x','date_y','count_y'],axis=1)

df.columns = df.columns.astype(str)

# %%
def forecast_random_pca(df):
    train_data, test_data = train_test_split(df, test_size=0.2, random_state=42)

    y_train = train_data['Close']
    y_test = test_data['Close']

    X_train = train_data.drop(['date', 'Close'], axis=1)
    X_test = test_data.drop(['date', 'Close'], axis=1)
    rf_model = RandomForestRegressor(n_estimators=200, random_state=42)
    rf_model.fit(X_train, y_train)

    predictions = rf_model.predict(X_test)

    last_30_days = df.tail(30).drop(['date', 'Close'], axis=1)
    next_30_days_predictions = rf_model.predict(last_30_days)
    return next_30_days_predictions

# %%
df
# Out:
#            date       Close     Volume  Stock Splits  Job_Value  \
# 1    2017-11-30  175.129303  2509300.0           0.0   70.31713
# 2    2017-12-12  175.129303  2509300.0           0.0   70.31713
# 3    2017-12-14  175.129303  2509300.0           0.0   70.31713
# 4    2018-01-02  175.129303  2509300.0           0.0   70.31713
# 5    2018-01-03  177.231033  3364400.0           0.0   70.31713
# ...         ...         ...        ...           ...        ...
# 1548 2023-06-06  516.260010  1410300.0           0.0   71.68311
# 1549 2023-06-07  511.230011  1784700.0           0.0   71.68311
# 1550 2023-06-08  520.090027  1530400.0           0.0   71.68311
# 1551 2023-06-09  517.280029  1287300.0           0.0   71.68311
# 1552 2023-06-10  517.280029  1287300.0           0.0   71.68311
#
#       Labour_values  Manufacturing_Value  CPI_Value  inflation_Value  \
# 1              41.0              197.900    248.859             2.07
# 2              41.0              197.900    248.859             2.07
# 3              41.0              197.900    248.859             2.07
# 4              41.0              197.900    248.859             2.07
# 5              41.0              197.900    248.859             2.07
# ...             ...                  ...        ...              ...
# 1548           42.0              259.904    300.536             6.41
# 1549           42.0              259.904    300.536             6.41
# 1550           42.0              259.904    300.536             6.41
# 1551           42.0              259.904    300.536             6.41
# 1552           42.0              259.904    300.536             6.41
#
#       Housing_value             0             1             2             3  \
# 1           310.828  1.385862e+14  2.043908e+14  6.212892e+13  3.573442e+14
# 2           310.828  1.385862e+14  2.043908e+14  6.212892e+13  3.573442e+14
# 3           310.828  1.385862e+14  2.043908e+14  6.212892e+13  3.573442e+14
# 4           310.828  1.385862e+14  2.043908e+14  6.212892e+13  3.573442e+14
# 5           310.828  1.385862e+14  2.043908e+14  6.212892e+13  3.573442e+14
# ...             ...           ...           ...           ...           ...
# 1548        377.000 -3.759507e+14 -5.544624e+14 -1.685406e+14 -9.693878e+14
# 1549        377.000 -3.759507e+14 -5.544624e+14 -1.685406e+14 -9.693878e+14
# 1550        377.000 -3.759507e+14 -5.544624e+14 -1.685406e+14 -9.693878e+14
# 1551        377.000 -3.759507e+14 -5.544624e+14 -1.685406e+14 -9.693878e+14
# 1552        377.000 -3.759507e+14 -5.544624e+14 -1.685406e+14 -9.693878e+14
#
#                  4             5  normalized  tweet_normalized
# 1     1.128857e+14  3.320616e+14      0.9030            0.1781
# 2     1.128857e+14  3.320616e+14      0.9930            0.1799
# 3     1.128857e+14  3.320616e+14      0.9940            0.2210
# 4     1.128857e+14  3.320616e+14      0.9940            0.2442
# 5     1.128857e+14  3.320616e+14      0.9940            0.2970
# ...            ...           ...         ...               ...
# 1548 -3.062315e+14 -9.008022e+14      0.5995            0.1755
# 1549 -3.062315e+14 -9.008022e+14      0.8890            0.1755
# 1550 -3.062315e+14 -9.008022e+14      0.6186            0.1755
# 1551 -3.062315e+14 -9.008022e+14      0.6186            0.1755
# 1552 -3.062315e+14 -9.008022e+14      0.4311            0.1755
#
# [1552 rows x 18 columns]

# %%
Random=forecast_random_pca(df)

# %%
lstm=lstm_predict(model, scaler, n_steps, n_features, df_lstm)
#b=lstm[0]
#b=round(b,2)
#st.write("Next Day Prediction for:")
#st.write(b)
#st.write(a[0])
#average[0]=(lstm[0]+Random[0])/2
ava=(lstm[0]+Random[0])/2
avb=(lstm[6]+Random[6])/2
avc=(lstm[14]+Random[14])/2

# %%
lstm[0]
# Out:
# 505.37903

# %%
Random[0]
# Out:
# 502.1140203857422

# %%
lstm[6]
# Out:
# 494.75613

# %%
Random[6]
# Out:
# 501.76071029663086

# %%
lstm[14]
# Out:
# 479.10565

# %%
Random[14]
# Out:
# 185.8778285217285

# %%
# !pip install pipdeptree
# Out:
# Collecting pipdeptree
#   Downloading pipdeptree-2.9.0-py3-none-any.whl (18 kB)
# Installing collected packages: pipdeptree
# Successfully installed pipdeptree-2.9.0
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -olorama (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboard (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -olorama (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboard (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -olorama (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboard (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -olorama (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboard (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -olorama (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboard (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -olorama (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboard (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -olorama (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboard (c:\programdata\anaconda3\lib\site-packages)

# %%
# !pipdeptree | findstr -P '^\w+'
# Out:
# Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# Ignoring invalid distribution -pencv-python (c:\programdata\anaconda3\lib\site-packages)
# Ignoring invalid distribution -olorama (c:\programdata\anaconda3\lib\site-packages)
# Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# Ignoring invalid distribution -ensorboard (c:\programdata\anaconda3\lib\site-packages)
# Warning!!! Possibly conflicting dependencies found:
# * conda-repo-cli==1.0.24
#  - clyent [required: ==1.2.1, installed: 1.2.2]
#  - nbformat [required: ==5.4.0, installed: 5.7.0]
# * daal4py==2021.6.0
#  - daal [required: ==2021.4.0, installed: ?]
# * en-core-web-sm==3.5.0
#  - spacy [required: >=3.5.0,<3.6.0, installed: 3.4.4]
# * gensim==4.1.2
#  - Cython [required: ==0.29.23, installed: 0.29.32]
# * spyder==5.2.2
#  - pyqtwebengine [required: <5.13, installed: ?]
#  - pyqt5 [required: <5.13, installed: ?]
# ------------------------------------------------------------------------
# Warning!! Cyclic dependencies found:
# * hub => deeplake => hub
# * deeplake => hub => deeplake
# * Naked => Naked => Naked
# ------------------------------------------------------------------------

# %%
picard.__version__
# Out:
# '0.7'

# %%
yf.__version__
# Out:
# '0.2.20'

# %%
# !pip freeze > reqs.txt
# Out:
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -olorama (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboard (c:\programdata\anaconda3\lib\site-packages)

# %%
import sklearn
sklearn.__version__
# Out:
# '1.0.2'
